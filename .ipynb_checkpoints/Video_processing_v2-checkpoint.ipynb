# %%
#git@github.com:analyticsrepo01/gemini_video.git

# %%
# !pip install -q --upgrade google-cloud-aiplatform
# !pip install -q google-cloud-videointelligence
# !pip install -q pytube
# !pip install -q unidecode
# !pip install -q varname
# !pip install -q -U 'crewai[tools]' mdpdf 
# !pip install -q langchain_google_vertexai
# !pip install -q moviepy
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kfp 2.5.0 requires kubernetes<27,>=8.0.0, but you have kubernetes 29.0.0 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kfp 2.5.0 requires kubernetes<27,>=8.0.0, but you have kubernetes 29.0.0 which is incompatible.
# kfp 2.5.0 requires urllib3<2.0.0, but you have urllib3 2.2.1 which is incompatible.

# %%
# %pip install google-cloud-videointelligence
# %pip install unidecode
# %pip install varname
# %pip install seaborn
# !sudo apt-get -q install -y ffmpeg
# Out:
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /opt/conda/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=0.25 in /opt/conda/lib/python3.10/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /opt/conda/lib/python3.10/site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   i965-va-driver intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0
#   libavc1394-0 libavcodec58 libavdevice58 libavfilter7 libavformat58
#   libavresample4 libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0
#   libcdio-cdda2 libcdio-paranoia2 libcdio19 libchromaprint1 libcodec2-0.9
#   libdav1d4 libdc1394-25 libfftw3-double3 libflac8 libflite1 libgbm1 libgme0
#   libgsm1 libiec61883-0 libigdgmm11 libjack-jackd2-0 liblilv-0-0 libmfx1
#   libmp3lame0 libmpg123-0 libmysofa1 libnorm1 libogg0 libopenal-data
#   libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpgm-5.3-0 libpocketsphinx3
#   libpostproc55 libpulse0 librabbitmq4 libraw1394-11 librubberband2
#   libsamplerate0 libsdl2-2.0-0 libserd-0-0 libshine3 libsndfile1 libsndio7.0
#   libsodium23 libsord-0-0 libsoxr0 libspeex1 libsphinxbase3 libsratom-0-0
#   libsrt1.4-gnutls libssh-gcrypt-4 libswresample3 libswscale5 libtheora0
#   libtwolame0 libudfread0 libusb-1.0-0 libva-drm2 libva-x11-2 libva2
#   libvdpau-va-gl1 libvdpau1 libvidstab1.1 libvorbis0a libvorbisenc2
#   libvorbisfile3 libvpx6 libwavpack1 libwayland-server0 libwebpmux3
#   libx264-160 libx265-192 libxvidcore4 libzmq5 libzvbi-common libzvbi0
#   mesa-va-drivers mesa-vdpau-drivers ocl-icd-libopencl1 pocketsphinx-en-us
#   va-driver-all vdpau-driver-all
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libbluray-bdj libfftw3-bin libfftw3-dev
#   jackd2 libportaudio2 opus-tools pulseaudio libraw1394-doc serdi sndiod sordi
#   speex opencl-icd nvidia-vdpau-driver nvidia-tesla-440-vdpau-driver
#   nvidia-tesla-418-vdpau-driver nvidia-legacy-390xx-vdpau-driver
#   nvidia-legacy-340xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg i965-va-driver intel-media-va-driver libaacs0 libaom0 libass9
#   libasyncns0 libavc1394-0 libavcodec58 libavdevice58 libavfilter7
#   libavformat58 libavresample4 libavutil56 libbdplus0 libbluray2 libbs2b0
#   libcaca0 libcdio-cdda2 libcdio-paranoia2 libcdio19 libchromaprint1
#   libcodec2-0.9 libdav1d4 libdc1394-25 libfftw3-double3 libflac8 libflite1
#   libgbm1 libgme0 libgsm1 libiec61883-0 libigdgmm11 libjack-jackd2-0
#   liblilv-0-0 libmfx1 libmp3lame0 libmpg123-0 libmysofa1 libnorm1 libogg0
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpgm-5.3-0
#   libpocketsphinx3 libpostproc55 libpulse0 librabbitmq4 libraw1394-11
#   librubberband2 libsamplerate0 libsdl2-2.0-0 libserd-0-0 libshine3
#   libsndfile1 libsndio7.0 libsodium23 libsord-0-0 libsoxr0 libspeex1
#   libsphinxbase3 libsratom-0-0 libsrt1.4-gnutls libssh-gcrypt-4 libswresample3
#   libswscale5 libtheora0 libtwolame0 libudfread0 libusb-1.0-0 libva-drm2
#   libva-x11-2 libva2 libvdpau-va-gl1 libvdpau1 libvidstab1.1 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx6 libwavpack1 libwayland-server0
#   libwebpmux3 libx264-160 libx265-192 libxvidcore4 libzmq5 libzvbi-common
#   libzvbi0 mesa-va-drivers mesa-vdpau-drivers ocl-icd-libopencl1
#   pocketsphinx-en-us va-driver-all vdpau-driver-all
# 0 upgraded, 98 newly installed, 0 to remove and 2 not upgraded.
# Need to get 81.3 MB of archives.
# After this operation, 220 MB of additional disk space will be used.
# Get:1 https://deb.debian.org/debian bullseye/main amd64 libaom0 amd64 1.0.0.errata1-3+deb11u1 [1120 kB]
# Get:2 https://deb.debian.org/debian bullseye/main amd64 libva2 amd64 2.10.0-1 [68.7 kB]
# Get:3 https://deb.debian.org/debian bullseye/main amd64 libmfx1 amd64 21.1.0-1 [3289 kB]
# Get:4 https://deb.debian.org/debian bullseye/main amd64 libva-drm2 amd64 2.10.0-1 [19.0 kB]
# Get:5 https://deb.debian.org/debian bullseye/main amd64 libva-x11-2 amd64 2.10.0-1 [24.0 kB]
# Get:6 https://deb.debian.org/debian bullseye/main amd64 libvdpau1 amd64 1.4-3 [29.4 kB]
# Get:7 https://deb.debian.org/debian bullseye/main amd64 ocl-icd-libopencl1 amd64 2.2.14-2 [42.5 kB]
# Get:8 https://deb.debian.org/debian bullseye/main amd64 libavutil56 amd64 7:4.3.6-0+deb11u1 [312 kB]
# Get:9 https://deb.debian.org/debian bullseye/main amd64 libcodec2-0.9 amd64 0.9.2-4 [7890 kB]
# Get:10 https://deb.debian.org/debian bullseye/main amd64 libdav1d4 amd64 0.7.1-3 [333 kB]
# Get:11 https://deb.debian.org/debian bullseye/main amd64 libgsm1 amd64 1.0.18-2 [27.7 kB]
# Get:12 https://deb.debian.org/debian bullseye/main amd64 libmp3lame0 amd64 3.100-3 [364 kB]
# Get:13 https://deb.debian.org/debian bullseye/main amd64 libopenjp2-7 amd64 2.4.0-3 [172 kB]
# Get:14 https://deb.debian.org/debian bullseye/main amd64 libopus0 amd64 1.3.1-0.1 [190 kB]
# Get:15 https://deb.debian.org/debian bullseye/main amd64 libshine3 amd64 3.1.1-2 [23.6 kB]
# Get:16 https://deb.debian.org/debian bullseye/main amd64 libspeex1 amd64 1.2~rc1.2-1.1 [55.4 kB]
# Get:17 https://deb.debian.org/debian bullseye/main amd64 libsoxr0 amd64 0.1.3-4 [77.8 kB]
# Get:18 https://deb.debian.org/debian bullseye/main amd64 libswresample3 amd64 7:4.3.6-0+deb11u1 [110 kB]
# Get:19 https://deb.debian.org/debian bullseye/main amd64 libogg0 amd64 1.3.4-0.1 [27.3 kB]
# Get:20 https://deb.debian.org/debian bullseye/main amd64 libtheora0 amd64 1.1.1+dfsg.1-15 [169 kB]
# Get:21 https://deb.debian.org/debian bullseye/main amd64 libtwolame0 amd64 0.4.0-2 [51.1 kB]
# Get:22 https://deb.debian.org/debian bullseye/main amd64 libvorbis0a amd64 1.3.7-1 [93.0 kB]
# Get:23 https://deb.debian.org/debian bullseye/main amd64 libvorbisenc2 amd64 1.3.7-1 [80.6 kB]
# Get:24 https://deb.debian.org/debian bullseye/main amd64 libvpx6 amd64 1.9.0-1+deb11u2 [829 kB]
# Get:25 https://deb.debian.org/debian bullseye/main amd64 libwavpack1 amd64 5.4.0-1 [87.8 kB]
# Get:26 https://deb.debian.org/debian bullseye/main amd64 libwebpmux3 amd64 0.6.1-2.1+deb11u2 [97.7 kB]
# Get:27 https://deb.debian.org/debian bullseye/main amd64 libx264-160 amd64 2:0.160.3011+gitcde9a93-2.1 [539 kB]
# Get:28 https://deb.debian.org/debian bullseye/main amd64 libx265-192 amd64 3.4-2 [1095 kB]
# Get:29 https://deb.debian.org/debian bullseye/main amd64 libxvidcore4 amd64 2:1.3.7-1 [242 kB]
# Get:30 https://deb.debian.org/debian bullseye/main amd64 libzvbi-common all 0.2.35-18 [64.6 kB]
# Get:31 https://deb.debian.org/debian bullseye/main amd64 libzvbi0 amd64 0.2.35-18 [271 kB]
# Get:32 https://deb.debian.org/debian bullseye/main amd64 libavcodec58 amd64 7:4.3.6-0+deb11u1 [4961 kB]
# Get:33 https://deb.debian.org/debian bullseye/main amd64 libraw1394-11 amd64 2.1.2-2 [41.1 kB]
# Get:34 https://deb.debian.org/debian bullseye/main amd64 libavc1394-0 amd64 0.5.4-5 [19.9 kB]
# Get:35 https://deb.debian.org/debian bullseye/main amd64 libass9 amd64 1:0.15.0-2 [100.0 kB]
# Get:36 https://deb.debian.org/debian bullseye/main amd64 libudfread0 amd64 1.1.1-1 [16.4 kB]
# Get:37 https://deb.debian.org/debian bullseye/main amd64 libbluray2 amd64 1:1.2.1-4+deb11u2 [139 kB]
# Get:38 https://deb.debian.org/debian bullseye/main amd64 libchromaprint1 amd64 1.5.0-2 [40.8 kB]
# Get:39 https://deb.debian.org/debian bullseye/main amd64 libgme0 amd64 0.6.3-2 [128 kB]
# Get:40 https://deb.debian.org/debian bullseye/main amd64 libmpg123-0 amd64 1.26.4-1 [142 kB]
# Get:41 https://deb.debian.org/debian bullseye/main amd64 libvorbisfile3 amd64 1.3.7-1 [26.1 kB]
# Get:42 https://deb.debian.org/debian bullseye/main amd64 libopenmpt0 amd64 0.4.11-1 [616 kB]
# Get:43 https://deb.debian.org/debian bullseye/main amd64 librabbitmq4 amd64 0.10.0-1 [41.0 kB]
# Get:44 https://deb.debian.org/debian bullseye/main amd64 libsrt1.4-gnutls amd64 1.4.2-1.3 [271 kB]
# Get:45 https://deb.debian.org/debian bullseye/main amd64 libssh-gcrypt-4 amd64 0.9.8-0+deb11u1 [221 kB]
# Get:46 https://deb.debian.org/debian bullseye/main amd64 libnorm1 amd64 1.5.9+dfsg-2 [221 kB]
# Get:47 https://deb.debian.org/debian bullseye/main amd64 libpgm-5.3-0 amd64 5.3.128~dfsg-2 [161 kB]
# Get:48 https://deb.debian.org/debian bullseye/main amd64 libsodium23 amd64 1.0.18-1 [161 kB]
# Get:49 https://deb.debian.org/debian bullseye/main amd64 libzmq5 amd64 4.3.4-1+deb11u1 [275 kB]
# Get:50 https://deb.debian.org/debian bullseye/main amd64 libavformat58 amd64 7:4.3.6-0+deb11u1 [1056 kB]
# Get:51 https://deb.debian.org/debian bullseye/main amd64 libbs2b0 amd64 3.1.0+dfsg-2.2+b1 [12.2 kB]
# Get:52 https://deb.debian.org/debian bullseye/main amd64 libflite1 amd64 2.2-2 [12.8 MB]
# Get:53 https://deb.debian.org/debian bullseye/main amd64 libserd-0-0 amd64 0.30.10-2 [46.0 kB]
# Get:54 https://deb.debian.org/debian bullseye/main amd64 libsord-0-0 amd64 0.16.8-2 [24.2 kB]
# Get:55 https://deb.debian.org/debian bullseye/main amd64 libsratom-0-0 amd64 0.6.8-1 [17.9 kB]
# Get:56 https://deb.debian.org/debian bullseye/main amd64 liblilv-0-0 amd64 0.24.12-2 [49.2 kB]
# Get:57 https://deb.debian.org/debian bullseye/main amd64 libmysofa1 amd64 1.2~dfsg0-1 [1157 kB]
# Get:58 https://deb.debian.org/debian bullseye/main amd64 libasyncns0 amd64 0.8-6+b2 [12.9 kB]
# Get:59 https://deb.debian.org/debian bullseye/main amd64 libflac8 amd64 1.3.3-2+deb11u2 [112 kB]
# Get:60 https://deb.debian.org/debian bullseye/main amd64 libsndfile1 amd64 1.0.31-2 [188 kB]
# Get:61 https://deb.debian.org/debian bullseye/main amd64 libpulse0 amd64 14.2-2 [285 kB]
# Get:62 https://deb.debian.org/debian bullseye/main amd64 libsphinxbase3 amd64 0.8+5prealpha+1-12 [120 kB]
# Get:63 https://deb.debian.org/debian bullseye/main amd64 libpocketsphinx3 amd64 0.8+5prealpha+1-13 [124 kB]
# Get:64 https://deb.debian.org/debian bullseye/main amd64 libpostproc55 amd64 7:4.3.6-0+deb11u1 [108 kB]
# Get:65 https://deb.debian.org/debian bullseye/main amd64 libfftw3-double3 amd64 3.3.8-2 [733 kB]
# Get:66 https://deb.debian.org/debian bullseye/main amd64 libsamplerate0 amd64 0.2.1+ds0-1 [954 kB]
# Get:67 https://deb.debian.org/debian bullseye/main amd64 librubberband2 amd64 1.9.0-1 [86.0 kB]
# Get:68 https://deb.debian.org/debian bullseye/main amd64 libswscale5 amd64 7:4.3.6-0+deb11u1 [211 kB]
# Get:69 https://deb.debian.org/debian bullseye/main amd64 libvidstab1.1 amd64 1.1.0-2+b1 [37.8 kB]
# Get:70 https://deb.debian.org/debian bullseye/main amd64 libavfilter7 amd64 7:4.3.6-0+deb11u1 [1300 kB]
# Get:71 https://deb.debian.org/debian bullseye/main amd64 libcaca0 amd64 0.99.beta19-2.2 [348 kB]
# Get:72 https://deb.debian.org/debian bullseye/main amd64 libcdio19 amd64 2.1.0-2 [204 kB]
# Get:73 https://deb.debian.org/debian bullseye/main amd64 libcdio-cdda2 amd64 10.2+2.0.0-1+b2 [20.7 kB]
# Get:74 https://deb.debian.org/debian bullseye/main amd64 libcdio-paranoia2 amd64 10.2+2.0.0-1+b2 [20.5 kB]
# Get:75 https://deb.debian.org/debian bullseye/main amd64 libusb-1.0-0 amd64 2:1.0.24-3 [60.2 kB]
# Get:76 https://deb.debian.org/debian bullseye/main amd64 libdc1394-25 amd64 2.2.6-3 [108 kB]
# Get:77 https://deb.debian.org/debian bullseye/main amd64 libiec61883-0 amd64 1.2.0-4 [31.4 kB]
# Get:78 https://deb.debian.org/debian bullseye/main amd64 libjack-jackd2-0 amd64 1.9.17~dfsg-1 [289 kB]
# Get:79 https://deb.debian.org/debian bullseye/main amd64 libopenal-data all 1:1.19.1-2 [170 kB]
# Get:80 https://deb.debian.org/debian bullseye/main amd64 libsndio7.0 amd64 1.5.0-3 [24.7 kB]
# Get:81 https://deb.debian.org/debian bullseye/main amd64 libopenal1 amd64 1:1.19.1-2 [501 kB]
# Get:82 https://deb.debian.org/debian bullseye/main amd64 libwayland-server0 amd64 1.18.0-2~exp1.1 [34.4 kB]
# Get:83 https://deb.debian.org/debian bullseye/main amd64 libgbm1 amd64 20.3.5-1 [73.5 kB]
# Get:84 https://deb.debian.org/debian bullseye/main amd64 libsdl2-2.0-0 amd64 2.0.14+dfsg2-3+deb11u1 [506 kB]
# Get:85 https://deb.debian.org/debian bullseye/main amd64 libavdevice58 amd64 7:4.3.6-0+deb11u1 [128 kB]
# Get:86 https://deb.debian.org/debian bullseye/main amd64 libavresample4 amd64 7:4.3.6-0+deb11u1 [106 kB]
# Get:87 https://deb.debian.org/debian bullseye/main amd64 ffmpeg amd64 7:4.3.6-0+deb11u1 [1599 kB]
# Get:88 https://deb.debian.org/debian bullseye/main amd64 i965-va-driver amd64 2.4.1+dfsg1-1 [309 kB]
# Get:89 https://deb.debian.org/debian bullseye/main amd64 libigdgmm11 amd64 20.4.1+ds1-1 [112 kB]
# Get:90 https://deb.debian.org/debian bullseye/main amd64 intel-media-va-driver amd64 21.1.1+dfsg1-1 [1915 kB]
# Get:91 https://deb.debian.org/debian bullseye/main amd64 libaacs0 amd64 0.9.0-2 [52.4 kB]
# Get:92 https://deb.debian.org/debian bullseye/main amd64 libbdplus0 amd64 0.1.2-3 [47.5 kB]
# Get:93 https://deb.debian.org/debian bullseye/main amd64 libvdpau-va-gl1 amd64 0.4.2-1+b1 [71.3 kB]
# Get:94 https://deb.debian.org/debian bullseye/main amd64 mesa-va-drivers amd64 20.3.5-1 [2623 kB]
# Get:95 https://deb.debian.org/debian bullseye/main amd64 mesa-vdpau-drivers amd64 20.3.5-1 [2744 kB]
# Get:96 https://deb.debian.org/debian bullseye/main amd64 pocketsphinx-en-us all 0.8+5prealpha+1-13 [24.3 MB]
# Get:97 https://deb.debian.org/debian bullseye/main amd64 va-driver-all amd64 2.10.0-1 [15.3 kB]
# Get:98 https://deb.debian.org/debian bullseye/main amd64 vdpau-driver-all amd64 1.4-3 [8540 B]
# Fetched 81.3 MB in 1s (96.1 MB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libaom0:amd64.
# (Reading database ... 136623 files and directories currently installed.)
# Preparing to unpack .../00-libaom0_1.0.0.errata1-3+deb11u1_amd64.deb ...
# Unpacking libaom0:amd64 (1.0.0.errata1-3+deb11u1) ...
# Selecting previously unselected package libva2:amd64.
# Preparing to unpack .../01-libva2_2.10.0-1_amd64.deb ...
# Unpacking libva2:amd64 (2.10.0-1) ...
# Selecting previously unselected package libmfx1:amd64.
# Preparing to unpack .../02-libmfx1_21.1.0-1_amd64.deb ...
# Unpacking libmfx1:amd64 (21.1.0-1) ...
# Selecting previously unselected package libva-drm2:amd64.
# Preparing to unpack .../03-libva-drm2_2.10.0-1_amd64.deb ...
# Unpacking libva-drm2:amd64 (2.10.0-1) ...
# Selecting previously unselected package libva-x11-2:amd64.
# Preparing to unpack .../04-libva-x11-2_2.10.0-1_amd64.deb ...
# Unpacking libva-x11-2:amd64 (2.10.0-1) ...
# Selecting previously unselected package libvdpau1:amd64.
# Preparing to unpack .../05-libvdpau1_1.4-3_amd64.deb ...
# Unpacking libvdpau1:amd64 (1.4-3) ...
# Selecting previously unselected package ocl-icd-libopencl1:amd64.
# Preparing to unpack .../06-ocl-icd-libopencl1_2.2.14-2_amd64.deb ...
# Unpacking ocl-icd-libopencl1:amd64 (2.2.14-2) ...
# Selecting previously unselected package libavutil56:amd64.
# Preparing to unpack .../07-libavutil56_7%3a4.3.6-0+deb11u1_amd64.deb ...
# Unpacking libavutil56:amd64 (7:4.3.6-0+deb11u1) ...
# Selecting previously unselected package libcodec2-0.9:amd64.
# Preparing to unpack .../08-libcodec2-0.9_0.9.2-4_amd64.deb ...
# Unpacking libcodec2-0.9:amd64 (0.9.2-4) ...
# Selecting previously unselected package libdav1d4:amd64.
# Preparing to unpack .../09-libdav1d4_0.7.1-3_amd64.deb ...
# Unpacking libdav1d4:amd64 (0.7.1-3) ...
# Selecting previously unselected package libgsm1:amd64.
# Preparing to unpack .../10-libgsm1_1.0.18-2_amd64.deb ...
# Unpacking libgsm1:amd64 (1.0.18-2) ...
# Selecting previously unselected package libmp3lame0:amd64.
# Preparing to unpack .../11-libmp3lame0_3.100-3_amd64.deb ...
# Unpacking libmp3lame0:amd64 (3.100-3) ...
# Selecting previously unselected package libopenjp2-7:amd64.
# Preparing to unpack .../12-libopenjp2-7_2.4.0-3_amd64.deb ...
# Unpacking libopenjp2-7:amd64 (2.4.0-3) ...
# Selecting previously unselected package libopus0:amd64.
# Preparing to unpack .../13-libopus0_1.3.1-0.1_amd64.deb ...
# Unpacking libopus0:amd64 (1.3.1-0.1) ...
# Selecting previously unselected package libshine3:amd64.
# Preparing to unpack .../14-libshine3_3.1.1-2_amd64.deb ...
# Unpacking libshine3:amd64 (3.1.1-2) ...
# Selecting previously unselected package libspeex1:amd64.
# Preparing to unpack .../15-libspeex1_1.2~rc1.2-1.1_amd64.deb ...
# Unpacking libspeex1:amd64 (1.2~rc1.2-1.1) ...
# Selecting previously unselected package libsoxr0:amd64.
# Preparing to unpack .../16-libsoxr0_0.1.3-4_amd64.deb ...
# Unpacking libsoxr0:amd64 (0.1.3-4) ...
# Selecting previously unselected package libswresample3:amd64.
# Preparing to unpack .../17-libswresample3_7%3a4.3.6-0+deb11u1_amd64.deb ...
# Unpacking libswresample3:amd64 (7:4.3.6-0+deb11u1) ...
# Selecting previously unselected package libogg0:amd64.
# Preparing to unpack .../18-libogg0_1.3.4-0.1_amd64.deb ...
# Unpacking libogg0:amd64 (1.3.4-0.1) ...
# Selecting previously unselected package libtheora0:amd64.
# Preparing to unpack .../19-libtheora0_1.1.1+dfsg.1-15_amd64.deb ...
# Unpacking libtheora0:amd64 (1.1.1+dfsg.1-15) ...
# Selecting previously unselected package libtwolame0:amd64.
# Preparing to unpack .../20-libtwolame0_0.4.0-2_amd64.deb ...
# Unpacking libtwolame0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libvorbis0a:amd64.
# Preparing to unpack .../21-libvorbis0a_1.3.7-1_amd64.deb ...
# Unpacking libvorbis0a:amd64 (1.3.7-1) ...
# Selecting previously unselected package libvorbisenc2:amd64.
# Preparing to unpack .../22-libvorbisenc2_1.3.7-1_amd64.deb ...
# Unpacking libvorbisenc2:amd64 (1.3.7-1) ...
# Selecting previously unselected package libvpx6:amd64.
# Preparing to unpack .../23-libvpx6_1.9.0-1+deb11u2_amd64.deb ...
# Unpacking libvpx6:amd64 (1.9.0-1+deb11u2) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../24-libwavpack1_5.4.0-1_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.4.0-1) ...
# Selecting previously unselected package libwebpmux3:amd64.
# Preparing to unpack .../25-libwebpmux3_0.6.1-2.1+deb11u2_amd64.deb ...
# Unpacking libwebpmux3:amd64 (0.6.1-2.1+deb11u2) ...
# Selecting previously unselected package libx264-160:amd64.
# Preparing to unpack .../26-libx264-160_2%3a0.160.3011+gitcde9a93-2.1_amd64.deb ...
# Unpacking libx264-160:amd64 (2:0.160.3011+gitcde9a93-2.1) ...
# Selecting previously unselected package libx265-192:amd64.
# Preparing to unpack .../27-libx265-192_3.4-2_amd64.deb ...
# Unpacking libx265-192:amd64 (3.4-2) ...
# Selecting previously unselected package libxvidcore4:amd64.
# Preparing to unpack .../28-libxvidcore4_2%3a1.3.7-1_amd64.deb ...
# Unpacking libxvidcore4:amd64 (2:1.3.7-1) ...
# Selecting previously unselected package libzvbi-common.
# Preparing to unpack .../29-libzvbi-common_0.2.35-18_all.deb ...
# Unpacking libzvbi-common (0.2.35-18) ...
# Selecting previously unselected package libzvbi0:amd64.
# Preparing to unpack .../30-libzvbi0_0.2.35-18_amd64.deb ...
# Unpacking libzvbi0:amd64 (0.2.35-18) ...
# Selecting previously unselected package libavcodec58:amd64.
# Preparing to unpack .../31-libavcodec58_7%3a4.3.6-0+deb11u1_amd64.deb ...
# Unpacking libavcodec58:amd64 (7:4.3.6-0+deb11u1) ...
# Selecting previously unselected package libraw1394-11:amd64.
# Preparing to unpack .../32-libraw1394-11_2.1.2-2_amd64.deb ...
# Unpacking libraw1394-11:amd64 (2.1.2-2) ...
# Selecting previously unselected package libavc1394-0:amd64.
# Preparing to unpack .../33-libavc1394-0_0.5.4-5_amd64.deb ...
# Unpacking libavc1394-0:amd64 (0.5.4-5) ...
# Selecting previously unselected package libass9:amd64.
# Preparing to unpack .../34-libass9_1%3a0.15.0-2_amd64.deb ...
# Unpacking libass9:amd64 (1:0.15.0-2) ...
# Selecting previously unselected package libudfread0:amd64.
# Preparing to unpack .../35-libudfread0_1.1.1-1_amd64.deb ...
# Unpacking libudfread0:amd64 (1.1.1-1) ...
# Selecting previously unselected package libbluray2:amd64.
# Preparing to unpack .../36-libbluray2_1%3a1.2.1-4+deb11u2_amd64.deb ...
# Unpacking libbluray2:amd64 (1:1.2.1-4+deb11u2) ...
# Selecting previously unselected package libchromaprint1:amd64.
# Preparing to unpack .../37-libchromaprint1_1.5.0-2_amd64.deb ...
# Unpacking libchromaprint1:amd64 (1.5.0-2) ...
# Selecting previously unselected package libgme0:amd64.
# Preparing to unpack .../38-libgme0_0.6.3-2_amd64.deb ...
# Unpacking libgme0:amd64 (0.6.3-2) ...
# Selecting previously unselected package libmpg123-0:amd64.
# Preparing to unpack .../39-libmpg123-0_1.26.4-1_amd64.deb ...
# Unpacking libmpg123-0:amd64 (1.26.4-1) ...
# Selecting previously unselected package libvorbisfile3:amd64.
# Preparing to unpack .../40-libvorbisfile3_1.3.7-1_amd64.deb ...
# Unpacking libvorbisfile3:amd64 (1.3.7-1) ...
# Selecting previously unselected package libopenmpt0:amd64.
# Preparing to unpack .../41-libopenmpt0_0.4.11-1_amd64.deb ...
# Unpacking libopenmpt0:amd64 (0.4.11-1) ...
# Selecting previously unselected package librabbitmq4:amd64.
# Preparing to unpack .../42-librabbitmq4_0.10.0-1_amd64.deb ...
# Unpacking librabbitmq4:amd64 (0.10.0-1) ...
# Selecting previously unselected package libsrt1.4-gnutls:amd64.
# Preparing to unpack .../43-libsrt1.4-gnutls_1.4.2-1.3_amd64.deb ...
# Unpacking libsrt1.4-gnutls:amd64 (1.4.2-1.3) ...
# Selecting previously unselected package libssh-gcrypt-4:amd64.
# Preparing to unpack .../44-libssh-gcrypt-4_0.9.8-0+deb11u1_amd64.deb ...
# Unpacking libssh-gcrypt-4:amd64 (0.9.8-0+deb11u1) ...
# Selecting previously unselected package libnorm1:amd64.
# Preparing to unpack .../45-libnorm1_1.5.9+dfsg-2_amd64.deb ...
# Unpacking libnorm1:amd64 (1.5.9+dfsg-2) ...
# Selecting previously unselected package libpgm-5.3-0:amd64.
# Preparing to unpack .../46-libpgm-5.3-0_5.3.128~dfsg-2_amd64.deb ...
# Unpacking libpgm-5.3-0:amd64 (5.3.128~dfsg-2) ...
# Selecting previously unselected package libsodium23:amd64.
# Preparing to unpack .../47-libsodium23_1.0.18-1_amd64.deb ...
# Unpacking libsodium23:amd64 (1.0.18-1) ...
# Selecting previously unselected package libzmq5:amd64.
# Preparing to unpack .../48-libzmq5_4.3.4-1+deb11u1_amd64.deb ...
# Unpacking libzmq5:amd64 (4.3.4-1+deb11u1) ...
# Selecting previously unselected package libavformat58:amd64.
# Preparing to unpack .../49-libavformat58_7%3a4.3.6-0+deb11u1_amd64.deb ...
# Unpacking libavformat58:amd64 (7:4.3.6-0+deb11u1) ...
# Selecting previously unselected package libbs2b0:amd64.
# Preparing to unpack .../50-libbs2b0_3.1.0+dfsg-2.2+b1_amd64.deb ...
# Unpacking libbs2b0:amd64 (3.1.0+dfsg-2.2+b1) ...
# Selecting previously unselected package libflite1:amd64.
# Preparing to unpack .../51-libflite1_2.2-2_amd64.deb ...
# Unpacking libflite1:amd64 (2.2-2) ...
# Selecting previously unselected package libserd-0-0:amd64.
# Preparing to unpack .../52-libserd-0-0_0.30.10-2_amd64.deb ...
# Unpacking libserd-0-0:amd64 (0.30.10-2) ...
# Selecting previously unselected package libsord-0-0:amd64.
# Preparing to unpack .../53-libsord-0-0_0.16.8-2_amd64.deb ...
# Unpacking libsord-0-0:amd64 (0.16.8-2) ...
# Selecting previously unselected package libsratom-0-0:amd64.
# Preparing to unpack .../54-libsratom-0-0_0.6.8-1_amd64.deb ...
# Unpacking libsratom-0-0:amd64 (0.6.8-1) ...
# Selecting previously unselected package liblilv-0-0:amd64.
# Preparing to unpack .../55-liblilv-0-0_0.24.12-2_amd64.deb ...
# Unpacking liblilv-0-0:amd64 (0.24.12-2) ...
# Selecting previously unselected package libmysofa1:amd64.
# Preparing to unpack .../56-libmysofa1_1.2~dfsg0-1_amd64.deb ...
# Unpacking libmysofa1:amd64 (1.2~dfsg0-1) ...
# Selecting previously unselected package libasyncns0:amd64.
# Preparing to unpack .../57-libasyncns0_0.8-6+b2_amd64.deb ...
# Unpacking libasyncns0:amd64 (0.8-6+b2) ...
# Selecting previously unselected package libflac8:amd64.
# Preparing to unpack .../58-libflac8_1.3.3-2+deb11u2_amd64.deb ...
# Unpacking libflac8:amd64 (1.3.3-2+deb11u2) ...
# Selecting previously unselected package libsndfile1:amd64.
# Preparing to unpack .../59-libsndfile1_1.0.31-2_amd64.deb ...
# Unpacking libsndfile1:amd64 (1.0.31-2) ...
# Selecting previously unselected package libpulse0:amd64.
# Preparing to unpack .../60-libpulse0_14.2-2_amd64.deb ...
# Unpacking libpulse0:amd64 (14.2-2) ...
# Selecting previously unselected package libsphinxbase3:amd64.
# Preparing to unpack .../61-libsphinxbase3_0.8+5prealpha+1-12_amd64.deb ...
# Unpacking libsphinxbase3:amd64 (0.8+5prealpha+1-12) ...
# Selecting previously unselected package libpocketsphinx3:amd64.
# Preparing to unpack .../62-libpocketsphinx3_0.8+5prealpha+1-13_amd64.deb ...
# Unpacking libpocketsphinx3:amd64 (0.8+5prealpha+1-13) ...
# Selecting previously unselected package libpostproc55:amd64.
# Preparing to unpack .../63-libpostproc55_7%3a4.3.6-0+deb11u1_amd64.deb ...
# Unpacking libpostproc55:amd64 (7:4.3.6-0+deb11u1) ...
# Selecting previously unselected package libfftw3-double3:amd64.
# Preparing to unpack .../64-libfftw3-double3_3.3.8-2_amd64.deb ...
# Unpacking libfftw3-double3:amd64 (3.3.8-2) ...
# Selecting previously unselected package libsamplerate0:amd64.
# Preparing to unpack .../65-libsamplerate0_0.2.1+ds0-1_amd64.deb ...
# Unpacking libsamplerate0:amd64 (0.2.1+ds0-1) ...
# Selecting previously unselected package librubberband2:amd64.
# Preparing to unpack .../66-librubberband2_1.9.0-1_amd64.deb ...
# Unpacking librubberband2:amd64 (1.9.0-1) ...
# Selecting previously unselected package libswscale5:amd64.
# Preparing to unpack .../67-libswscale5_7%3a4.3.6-0+deb11u1_amd64.deb ...
# Unpacking libswscale5:amd64 (7:4.3.6-0+deb11u1) ...
# Selecting previously unselected package libvidstab1.1:amd64.
# Preparing to unpack .../68-libvidstab1.1_1.1.0-2+b1_amd64.deb ...
# Unpacking libvidstab1.1:amd64 (1.1.0-2+b1) ...
# Selecting previously unselected package libavfilter7:amd64.
# Preparing to unpack .../69-libavfilter7_7%3a4.3.6-0+deb11u1_amd64.deb ...
# Unpacking libavfilter7:amd64 (7:4.3.6-0+deb11u1) ...
# Selecting previously unselected package libcaca0:amd64.
# Preparing to unpack .../70-libcaca0_0.99.beta19-2.2_amd64.deb ...
# Unpacking libcaca0:amd64 (0.99.beta19-2.2) ...
# Selecting previously unselected package libcdio19:amd64.
# Preparing to unpack .../71-libcdio19_2.1.0-2_amd64.deb ...
# Unpacking libcdio19:amd64 (2.1.0-2) ...
# Selecting previously unselected package libcdio-cdda2:amd64.
# Preparing to unpack .../72-libcdio-cdda2_10.2+2.0.0-1+b2_amd64.deb ...
# Unpacking libcdio-cdda2:amd64 (10.2+2.0.0-1+b2) ...
# Selecting previously unselected package libcdio-paranoia2:amd64.
# Preparing to unpack .../73-libcdio-paranoia2_10.2+2.0.0-1+b2_amd64.deb ...
# Unpacking libcdio-paranoia2:amd64 (10.2+2.0.0-1+b2) ...
# Selecting previously unselected package libusb-1.0-0:amd64.
# Preparing to unpack .../74-libusb-1.0-0_2%3a1.0.24-3_amd64.deb ...
# Unpacking libusb-1.0-0:amd64 (2:1.0.24-3) ...
# Selecting previously unselected package libdc1394-25:amd64.
# Preparing to unpack .../75-libdc1394-25_2.2.6-3_amd64.deb ...
# Unpacking libdc1394-25:amd64 (2.2.6-3) ...
# Selecting previously unselected package libiec61883-0:amd64.
# Preparing to unpack .../76-libiec61883-0_1.2.0-4_amd64.deb ...
# Unpacking libiec61883-0:amd64 (1.2.0-4) ...
# Selecting previously unselected package libjack-jackd2-0:amd64.
# Preparing to unpack .../77-libjack-jackd2-0_1.9.17~dfsg-1_amd64.deb ...
# Unpacking libjack-jackd2-0:amd64 (1.9.17~dfsg-1) ...
# Selecting previously unselected package libopenal-data.
# Preparing to unpack .../78-libopenal-data_1%3a1.19.1-2_all.deb ...
# Unpacking libopenal-data (1:1.19.1-2) ...
# Selecting previously unselected package libsndio7.0:amd64.
# Preparing to unpack .../79-libsndio7.0_1.5.0-3_amd64.deb ...
# Unpacking libsndio7.0:amd64 (1.5.0-3) ...
# Selecting previously unselected package libopenal1:amd64.
# Preparing to unpack .../80-libopenal1_1%3a1.19.1-2_amd64.deb ...
# Unpacking libopenal1:amd64 (1:1.19.1-2) ...
# Selecting previously unselected package libwayland-server0:amd64.
# Preparing to unpack .../81-libwayland-server0_1.18.0-2~exp1.1_amd64.deb ...
# Unpacking libwayland-server0:amd64 (1.18.0-2~exp1.1) ...
# Selecting previously unselected package libgbm1:amd64.
# Preparing to unpack .../82-libgbm1_20.3.5-1_amd64.deb ...
# Unpacking libgbm1:amd64 (20.3.5-1) ...
# Selecting previously unselected package libsdl2-2.0-0:amd64.
# Preparing to unpack .../83-libsdl2-2.0-0_2.0.14+dfsg2-3+deb11u1_amd64.deb ...
# Unpacking libsdl2-2.0-0:amd64 (2.0.14+dfsg2-3+deb11u1) ...
# Selecting previously unselected package libavdevice58:amd64.
# Preparing to unpack .../84-libavdevice58_7%3a4.3.6-0+deb11u1_amd64.deb ...
# Unpacking libavdevice58:amd64 (7:4.3.6-0+deb11u1) ...
# Selecting previously unselected package libavresample4:amd64.
# Preparing to unpack .../85-libavresample4_7%3a4.3.6-0+deb11u1_amd64.deb ...
# Unpacking libavresample4:amd64 (7:4.3.6-0+deb11u1) ...
# Selecting previously unselected package ffmpeg.
# Preparing to unpack .../86-ffmpeg_7%3a4.3.6-0+deb11u1_amd64.deb ...
# Unpacking ffmpeg (7:4.3.6-0+deb11u1) ...
# Selecting previously unselected package i965-va-driver:amd64.
# Preparing to unpack .../87-i965-va-driver_2.4.1+dfsg1-1_amd64.deb ...
# Unpacking i965-va-driver:amd64 (2.4.1+dfsg1-1) ...
# Selecting previously unselected package libigdgmm11:amd64.
# Preparing to unpack .../88-libigdgmm11_20.4.1+ds1-1_amd64.deb ...
# Unpacking libigdgmm11:amd64 (20.4.1+ds1-1) ...
# Selecting previously unselected package intel-media-va-driver:amd64.
# Preparing to unpack .../89-intel-media-va-driver_21.1.1+dfsg1-1_amd64.deb ...
# Unpacking intel-media-va-driver:amd64 (21.1.1+dfsg1-1) ...
# Selecting previously unselected package libaacs0:amd64.
# Preparing to unpack .../90-libaacs0_0.9.0-2_amd64.deb ...
# Unpacking libaacs0:amd64 (0.9.0-2) ...
# Selecting previously unselected package libbdplus0:amd64.
# Preparing to unpack .../91-libbdplus0_0.1.2-3_amd64.deb ...
# Unpacking libbdplus0:amd64 (0.1.2-3) ...
# Selecting previously unselected package libvdpau-va-gl1:amd64.
# Preparing to unpack .../92-libvdpau-va-gl1_0.4.2-1+b1_amd64.deb ...
# Unpacking libvdpau-va-gl1:amd64 (0.4.2-1+b1) ...
# Selecting previously unselected package mesa-va-drivers:amd64.
# Preparing to unpack .../93-mesa-va-drivers_20.3.5-1_amd64.deb ...
# Unpacking mesa-va-drivers:amd64 (20.3.5-1) ...
# Selecting previously unselected package mesa-vdpau-drivers:amd64.
# Preparing to unpack .../94-mesa-vdpau-drivers_20.3.5-1_amd64.deb ...
# Unpacking mesa-vdpau-drivers:amd64 (20.3.5-1) ...
# Selecting previously unselected package pocketsphinx-en-us.
# Preparing to unpack .../95-pocketsphinx-en-us_0.8+5prealpha+1-13_all.deb ...
# Unpacking pocketsphinx-en-us (0.8+5prealpha+1-13) ...
# Selecting previously unselected package va-driver-all:amd64.
# Preparing to unpack .../96-va-driver-all_2.10.0-1_amd64.deb ...
# Unpacking va-driver-all:amd64 (2.10.0-1) ...
# Selecting previously unselected package vdpau-driver-all:amd64.
# Preparing to unpack .../97-vdpau-driver-all_1.4-3_amd64.deb ...
# Unpacking vdpau-driver-all:amd64 (1.4-3) ...
# Setting up libgme0:amd64 (0.6.3-2) ...
# Setting up libssh-gcrypt-4:amd64 (0.9.8-0+deb11u1) ...
# Setting up libsrt1.4-gnutls:amd64 (1.4.2-1.3) ...
# Setting up libudfread0:amd64 (1.1.1-1) ...
# Setting up libwayland-server0:amd64 (1.18.0-2~exp1.1) ...
# Setting up librabbitmq4:amd64 (0.10.0-1) ...
# Setting up libraw1394-11:amd64 (2.1.2-2) ...
# Setting up libsodium23:amd64 (1.0.18-1) ...
# Setting up libmpg123-0:amd64 (1.26.4-1) ...
# Setting up libogg0:amd64 (1.3.4-0.1) ...
# Setting up libspeex1:amd64 (1.2~rc1.2-1.1) ...
# Setting up libshine3:amd64 (3.1.1-2) ...
# Setting up libcaca0:amd64 (0.99.beta19-2.2) ...
# Setting up libtwolame0:amd64 (0.4.0-2) ...
# Setting up libgbm1:amd64 (20.3.5-1) ...
# Setting up libgsm1:amd64 (1.0.18-2) ...
# Setting up libsoxr0:amd64 (0.1.3-4) ...
# Setting up libpgm-5.3-0:amd64 (5.3.128~dfsg-2) ...
# Setting up libaom0:amd64 (1.0.0.errata1-3+deb11u1) ...
# Setting up libnorm1:amd64 (1.5.9+dfsg-2) ...
# Setting up libmysofa1:amd64 (1.2~dfsg0-1) ...
# Setting up libx265-192:amd64 (3.4-2) ...
# Setting up libcdio19:amd64 (2.1.0-2) ...
# Setting up libxvidcore4:amd64 (2:1.3.7-1) ...
# Setting up libx264-160:amd64 (2:0.160.3011+gitcde9a93-2.1) ...
# Setting up libflac8:amd64 (1.3.3-2+deb11u2) ...
# Setting up libass9:amd64 (1:0.15.0-2) ...
# Setting up libva2:amd64 (2.10.0-1) ...
# Setting up libigdgmm11:amd64 (20.4.1+ds1-1) ...
# Setting up libcodec2-0.9:amd64 (0.9.2-4) ...
# Setting up libopus0:amd64 (1.3.1-0.1) ...
# Setting up intel-media-va-driver:amd64 (21.1.1+dfsg1-1) ...
# Setting up libvorbis0a:amd64 (1.3.7-1) ...
# Setting up libaacs0:amd64 (0.9.0-2) ...
# Setting up pocketsphinx-en-us (0.8+5prealpha+1-13) ...
# Setting up libfftw3-double3:amd64 (3.3.8-2) ...
# Setting up libsndio7.0:amd64 (1.5.0-3) ...
# Setting up libbdplus0:amd64 (0.1.2-3) ...
# Setting up libvidstab1.1:amd64 (1.1.0-2+b1) ...
# Setting up libflite1:amd64 (2.2-2) ...
# Setting up libva-drm2:amd64 (2.10.0-1) ...
# Setting up ocl-icd-libopencl1:amd64 (2.2.14-2) ...
# Setting up libasyncns0:amd64 (0.8-6+b2) ...
# Setting up libvpx6:amd64 (1.9.0-1+deb11u2) ...
# Setting up libvdpau1:amd64 (1.4-3) ...
# Setting up libwavpack1:amd64 (5.4.0-1) ...
# Setting up libbs2b0:amd64 (3.1.0+dfsg-2.2+b1) ...
# Setting up libtheora0:amd64 (1.1.1+dfsg.1-15) ...
# Setting up libdav1d4:amd64 (0.7.1-3) ...
# Setting up libopenjp2-7:amd64 (2.4.0-3) ...
# Setting up libopenal-data (1:1.19.1-2) ...
# Setting up libusb-1.0-0:amd64 (2:1.0.24-3) ...
# Setting up mesa-va-drivers:amd64 (20.3.5-1) ...
# Setting up libmfx1:amd64 (21.1.0-1) ...
# Setting up libbluray2:amd64 (1:1.2.1-4+deb11u2) ...
# Setting up libsamplerate0:amd64 (0.2.1+ds0-1) ...
# Setting up libva-x11-2:amd64 (2.10.0-1) ...
# Setting up libwebpmux3:amd64 (0.6.1-2.1+deb11u2) ...
# Setting up libvdpau-va-gl1:amd64 (0.4.2-1+b1) ...
# Setting up libzvbi-common (0.2.35-18) ...
# Setting up libmp3lame0:amd64 (3.100-3) ...
# Setting up i965-va-driver:amd64 (2.4.1+dfsg1-1) ...
# Setting up libvorbisenc2:amd64 (1.3.7-1) ...
# Setting up libiec61883-0:amd64 (1.2.0-4) ...
# Setting up libserd-0-0:amd64 (0.30.10-2) ...
# Setting up libavc1394-0:amd64 (0.5.4-5) ...
# Setting up mesa-vdpau-drivers:amd64 (20.3.5-1) ...
# Setting up libzvbi0:amd64 (0.2.35-18) ...
# Setting up libzmq5:amd64 (4.3.4-1+deb11u1) ...
# Setting up libcdio-cdda2:amd64 (10.2+2.0.0-1+b2) ...
# Setting up libcdio-paranoia2:amd64 (10.2+2.0.0-1+b2) ...
# Setting up libopenal1:amd64 (1:1.19.1-2) ...
# Setting up libavutil56:amd64 (7:4.3.6-0+deb11u1) ...
# Setting up libvorbisfile3:amd64 (1.3.7-1) ...
# Setting up va-driver-all:amd64 (2.10.0-1) ...
# Setting up libdc1394-25:amd64 (2.2.6-3) ...
# Setting up libpostproc55:amd64 (7:4.3.6-0+deb11u1) ...
# Setting up librubberband2:amd64 (1.9.0-1) ...
# Setting up libjack-jackd2-0:amd64 (1.9.17~dfsg-1) ...
# Setting up vdpau-driver-all:amd64 (1.4-3) ...
# Setting up libsord-0-0:amd64 (0.16.8-2) ...
# Setting up libsratom-0-0:amd64 (0.6.8-1) ...
# Setting up libswscale5:amd64 (7:4.3.6-0+deb11u1) ...
# Setting up libsndfile1:amd64 (1.0.31-2) ...
# Setting up liblilv-0-0:amd64 (0.24.12-2) ...
# Setting up libopenmpt0:amd64 (0.4.11-1) ...
# Setting up libpulse0:amd64 (14.2-2) ...
# Setting up libswresample3:amd64 (7:4.3.6-0+deb11u1) ...
# Setting up libavresample4:amd64 (7:4.3.6-0+deb11u1) ...
# Setting up libavcodec58:amd64 (7:4.3.6-0+deb11u1) ...
# Setting up libsdl2-2.0-0:amd64 (2.0.14+dfsg2-3+deb11u1) ...
# Setting up libchromaprint1:amd64 (1.5.0-2) ...
# Setting up libsphinxbase3:amd64 (0.8+5prealpha+1-12) ...
# Setting up libavformat58:amd64 (7:4.3.6-0+deb11u1) ...
# Setting up libpocketsphinx3:amd64 (0.8+5prealpha+1-13) ...
# Setting up libavfilter7:amd64 (7:4.3.6-0+deb11u1) ...
# Setting up libavdevice58:amd64 (7:4.3.6-0+deb11u1) ...
# Setting up ffmpeg (7:4.3.6-0+deb11u1) ...
# Processing triggers for man-db (2.9.4-2) ...
# Processing triggers for libc-bin (2.31-13+deb11u8) ...
# ldconfig: /lib/libnvinfer_dispatch.so.8 is not a symbolic link
#
# ldconfig: /lib/libnvinfer_plugin.so.8 is not a symbolic link
#
# ldconfig: /lib/libnvparsers.so.8 is not a symbolic link
#
# ldconfig: /lib/libnvinfer_lean.so.8 is not a symbolic link
#
# ldconfig: /lib/libnvinfer.so.8 is not a symbolic link
#
# ldconfig: /lib/libnvinfer_vc_plugin.so.8 is not a symbolic link
#
# ldconfig: /lib/libnvonnxparser.so.8 is not a symbolic link

# %%
"""Transcribe speech from a video stored on GCS."""
from google.cloud import videointelligence
from pytube import YouTube
# Install pytube if not already installed
from pytube import YouTube
from google.cloud import storage
import vertexai
import json
import unidecode
from varname import nameof

import pandas as pd
import seaborn as sns
from IPython.display import Markdown, display
from sklearn.metrics.pairwise import cosine_similarity
from vertexai.preview.language_models import (ChatModel, InputOutputTextPair,
                                              TextEmbeddingModel,
                                              TextGenerationModel)
from vertexai.generative_models import GenerativeModel

import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, FinishReason

# %% [markdown]
# ### 1.1) Setup

# %%
import socket
import re

PROJECT_ID = !(gcloud config get-value core/project)
PROJECT_ID = PROJECT_ID[0]

SVC_ACC = !(gcloud config get-value core/account)
SVC_ACC = SVC_ACC[0]

PROJECT_NUMBER=str(re.search(r'\d+', SVC_ACC).group())

LOCATION="asia-southeast1"

UNIQUE_PREFIX = socket.gethostname()
UNIQUE_PREFIX = re.sub('[^A-Za-z0-9]+', '', UNIQUE_PREFIX)

BUCKET_NAME = f"{PROJECT_ID}-{UNIQUE_PREFIX}-{LOCATION}"

BUCKET_URI = f"gs://{BUCKET_NAME}"  # @param {type:"string"}

! gcloud config set project $PROJECT_ID
! gcloud storage buckets create {BUCKET_URI} --project={PROJECT_ID} --location={LOCATION}
! mkdir output
# Out:
# Updated property [core/project].
# Creating gs://mythical-lens-406709-renzinstance3-asia-southeast1/...

# %%
import vertexai
from vertexai.preview.generative_models import GenerativeModel, Part

from crewai import Agent, Task, Crew, Process
from crewai_tools import tool
# from langchain_vertexai import ChatGemini
from crewai_tools.tools import FileReadTool
import os, requests, re, mdpdf, subprocess
from vertexai.preview.vision_models import ImageGenerationModel
from langchain_google_vertexai import ChatVertexAI
import uuid, os

# Initialize Gemini LLM
llm = ChatVertexAI(
    # model_name="gemini-pro", # Replace with your desired Gemini model
    # model = GenerativeModel("gemini-pro")
    # model = GenerativeModel("gemini-1.5-pro-preview-0215")
    model = "gemini-1.5-pro-preview-0409",
    project_id=os.getenv(PROJECT_ID), # Your Vertex AI project ID
    location="us-central1", # Your Vertex AI location
)


def generate_pro(input_prompt):
    model = GenerativeModel("gemini-1.5-pro-preview-0409")
    full_prompt = '''summarize the prompt below and do note prompt below will be send to imagen mode so please clean up any sensitve words and replace them into unblocked words like replace girl or lady can be replaced by female human and so on : ''' + input_prompt
    responses = model.generate_content(
    input_prompt,
    generation_config={
        "max_output_tokens": 8190,
        "temperature": 0.2,
        "top_p": 1
    },stream=False,)
    
    # print (responses.text)
    
    return(responses.text)

# %%
def generate(input_array, max_output_tokens=8192, temperature=1, top_p=0.95):
    model = GenerativeModel("gemini-1.5-pro-preview-0409")
    params = {}
    params["safety_settings"] = {
        generative_models.HarmCategory.HARM_CATEGORY_HATE_SPEECH: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
        generative_models.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
        generative_models.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
        generative_models.HarmCategory.HARM_CATEGORY_HARASSMENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    }
    params["generation_config"] = {"max_output_tokens": max_output_tokens,"temperature": temperature,"top_p": top_p}
    params["stream"] = True
    ##responses = model.generate_content(input_array,generation_config=generation_config,safety_settings=safety_settings, stream=True)
    responses = model.generate_content(input_array,**params)
    return responses

# %%
from google.cloud import storage
# -1) Helper functions for bucket management
# -1.1) Fetching from youtube
def download_video(video_url):
    # Create a YouTube object
    yt = YouTube(video_url)
    
    # Filter to get the highest resolution stream that includes both video and audio
    stream = yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first()
    
    # Download the video
    if stream:
        print(f"Going to download {video_url}")
        stream.download()
        print(f"Downloaded into {stream.default_filename}")
    else:
        print("No suitable stream found")
    return stream.default_filename
def upload_video_sur_bucket(video_url):
    downloaded_video     = download_video(video_url)
    uploaded_video       = upload_file_to_bucket(bucket_name, downloaded_video)
    
    uri_video_sur_bucket = f"gs://{bucket_name}/{uploaded_video}"

    return uri_video_sur_bucket
# -1.2) Managing buckets
def list_buckets_names():
    storage_client = storage.Client()
    buckets        = storage_client.list_buckets()
    return [bucket.name for bucket in buckets]


def create_bucket_class_location(bucket_name, storage_class = "STANDARD", location="us"):
    storage_client       = storage.Client()
    bucket               = storage_client.bucket(bucket_name)
    bucket.storage_class = storage_class
    new_bucket           = storage_client.create_bucket(bucket, location=location)
    print(f"Created bucket {new_bucket.name} in {new_bucket.location} with storage class {new_bucket.storage_class}")
    return new_bucket


def upload_file_to_gcs(bucket_name, source_file_path, destination_blob_name):
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)
    blob.upload_from_filename(source_file_path)
    return blob
def upload_file_to_bucket(bucket_name, source_file_path_name): 
    source_file_path = f"./{source_file_path_name}"
    destination_blob_name = source_file_path_name.replace(' ', '_')
    destination_blob_name = unidecode.unidecode(destination_blob_name)
    uploaded_blob         = upload_file_to_gcs(bucket_name, source_file_path, destination_blob_name)
    os.rename(f'{source_file_path_name}', f'{destination_blob_name}')
    print(f"File [{source_file_path}] \nUploaded to [{uploaded_blob.name}] \nIn bucket [{bucket_name}]")
    return destination_blob_name
def create_bucket_if_doesnt_exist(bucket_name):
    if bucket_name not in list_buckets_names():
        print(f"Going to create bucket :{bucket_name}")
        create_bucket_class_location(bucket_name)
        
    assert(bucket_name in list_buckets_names())

    
# - 1.3) 🔥 Calling Gemini 🔥 (the magic is here ! )
def generate(input_array, max_output_tokens=8192, temperature=1, top_p=0.95):
    model = GenerativeModel("gemini-1.5-pro-preview-0409")
    params = {}
    params["safety_settings"] = {
        generative_models.HarmCategory.HARM_CATEGORY_HATE_SPEECH: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
        generative_models.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
        generative_models.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
        generative_models.HarmCategory.HARM_CATEGORY_HARASSMENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    }
    params["generation_config"] = {"max_output_tokens": max_output_tokens,"temperature": temperature,"top_p": top_p}
    params["stream"] = True
    ##responses = model.generate_content(input_array,generation_config=generation_config,safety_settings=safety_settings, stream=True)
    responses = model.generate_content(input_array,**params)
    return responses

# %%
# Define the video URL
video_url = "https://www.youtube.com/watch?v=V6DJYGn2SFk"

# %%
vertexai.init(project=PROJECT_ID, location=LOCATION)

# %%
# 1.2) transfer youtube video to the bucket

downloaded_video = download_video(video_url)
uploaded_video = upload_file_to_bucket(BUCKET_NAME, downloaded_video)
# Out:
# Going to download https://www.youtube.com/watch?v=V6DJYGn2SFk
# Downloaded into Google Cloud Next 24 Opening Keynote.mp4
# File [./Google Cloud Next 24 Opening Keynote.mp4]
# Uploaded to [Google_Cloud_Next_24_Opening_Keynote.mp4]
# In bucket [mythical-lens-406709-renzinstance3-asia-southeast1]

# %%
from vertexai.generative_models import GenerativeModel

import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, FinishReason
import vertexai.preview.generative_models as generative_models

# %%
import os

filename = uploaded_video
base_name = os.path.basename(filename)  # Get the base filename
name_without_ext = os.path.splitext(base_name)[0]  # Split off the extension 

print(base_name)
# Out:
# Google_Cloud_Next_24_Opening_Keynote.mp4

# %% [markdown]
# ### 1.2) Split the video into chunks for batch processing

# %%
! ffmpeg -i {base_name} -c copy -map 0 -f segment -segment_time 300 -reset_timestamps 1 output/{name_without_ext}_%02d.mp4
# Out:
# ffmpeg version 4.3.6-0+deb11u1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 10 (Debian 10.2.1-6)
#   configuration: --prefix=/usr --extra-version=0+deb11u1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'Google_Cloud_Next_24_Opening_Keynote.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2024-04-10T11:34:47.000000Z
#   Duration: 01:40:41.86, start: 0.000000, bitrate: 997 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 866 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2024-04-10T11:34:47.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/10/2024.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2024-04-10T11:34:47.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/10/2024.
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_00.mp4' for writing
# Output #0, segment, to 'output/Google_Cloud_Next_24_Opening_Keynote_%02d.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 866 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 29.97 tbc (default)
#     Metadata:
#       creation_time   : 2024-04-10T11:34:47.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/10/2024.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2024-04-10T11:34:47.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/10/2024.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_01.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_02.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_03.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_04.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_05.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_06.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_07.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_08.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_09.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_10.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_11.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_12.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_13.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_14.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_15.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_16.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_17.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_18.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_19.mp4' for writing
# [segment @ 0x557deebba840] Opening 'output/Google_Cloud_Next_24_Opening_Keynote_20.mp4' for writing
# frame=181074 fps=40037 q=-1.0 Lsize=N/A time=01:40:41.83 bitrate=N/A speed=1.34e+03x
# video:638983kB audio:94404kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
directory = 'output/'

def get_creation_time(item):
        item_path = os.path.join(directory, item)
        return os.path.getctime(item_path)

entries = os.listdir(directory)
sorted_items = sorted(entries, key=get_creation_time)
videos = []
for video in sorted_items:
    upload_file_to_gcs(BUCKET_NAME, f"{directory}{video}", f"{directory}{video}")

# %%
storage_client = storage.Client()
bucket = storage_client.bucket(BUCKET_NAME)
blob_names = [blob.name for blob in bucket.list_blobs(prefix = "output/")]

videos=[]
for blob in blob_names:
    uri_video_sur_bucket = f"gs://{BUCKET_NAME}/{blob}"
    mime_type = "video/mp4"
    parameters = {"mime_type"  : mime_type, 
                  "uri"        : uri_video_sur_bucket }
    videos.append(Part.from_uri(**parameters))

# %% [markdown]
# ### 1.3) Add the video as a Part of the model

# %%
response_list = []
for video in videos:
    prompt = """"Create a chapter index for this video and generate a nice HTML code to present the chapter index."""
    responses = generate([prompt, video])
    response_list.append(responses)

# %%
result = []
for responses in response_list:
    for response in responses :
        print(".",end="")
        result.append(response.text)
# Out:
# ....................................................................................................................................................................................................................................

# %%
print("\n".join(result))
# Out:
# ## Google
#  Cloud Next '23 Opening Keynote Chapter Index
#
# While I don't have access to the specific content of the video, I can create a general chapter index
#  based on common themes in such keynotes and the provided transcript excerpt:
#
# **HTML Code:**
#
# ```html
# <!DOCTYPE html>
# <html>
#
# <head>
# <title>Google Cloud Next '23 Opening Keynote - Chapter Index</title>
# <style>
# body { font-family: sans-serif; }
# h2 { color: #3367d6; } /* Google blue */
# ul { list-style: none
# ; padding: 0; }
# li a { display: block; padding: 8px; text-decoration: none; color: #000; }
# li a:hover { background-color: #eee; }
# </style>
# </head>
# <body>
# <h1>Google
#  Cloud Next '23 Opening Keynote - Chapter Index</h1>
#
# <h2>Introduction (00:00 - 01:43)</h2>
# <ul>
#   <li><a href="#intro">Opening and Welcome</a></li>
#   <li><a href="#ai-today">AI as a Today Thing - Examples of Impact</a></li>
# </ul>
#
# <h2>Thomas Kurian Keynote (01:43 - 0
# 3:34)</h2>
# <ul>
#   <li><a href="#progress">Google Cloud Progress and Achievements</a></li>
#   <li><a href="#infrastructure">Infrastructure Expansion and Investments</a></li>
#   <li><a href="#ai-adoption">Generative AI Adoption and Growth</a></li>
# </ul>
#
# <h2>Sundar Pichai Keynote (03:34 - )</h2>
# <ul>
#
#   <li><a href="#cloud-momentum">Cloud Business Momentum and Growth</a></li>
#   <li><a href="#ai-investments">Deep Investments in AI and TPUs</a></li>
#   <li><a href="#future-vision">Vision for the Future of AI and Cloud</a></li>
#   <!-- Additional chapters can be added based on the actual content -->
# </ul>
#
# </body>
# </html>
# ```
#
# **Explanation:**
#
# *   **Headers:** We use `<h1>` for the main title and `<h2>` for the section titles
# .
# *   **Styling:** Basic CSS is included to style the text and links, using Google's blue color for section headers.
# *   **Links:** Each chapter title is linked with an `href` attribute. You would replace the `#intro`, `#ai-today`, etc. with the actual timestamps or video section IDs.
# *   **Chapters:** The chapter titles are generic, but you should customize them to reflect the actual content of the video.
#
# **To use this code:**
#
# 1.  Save the code as an HTML file (e.g., `index.html`).
# 2.
#   Replace the placeholder links with the actual video timestamps or section IDs.
# 3.  Open the HTML file in a web browser to view the chapter index.
#
# **Additional Tips:**
#
# *   You can add more chapters and sections as needed.
# *   Consider adding timestamps to each chapter title for easier navigation.
# *   You can further customize the styling to match your preferences.
# *   If the video platform offers chapter functionality, you might be able to directly integrate this index with the video player.
#
# ## Chapter
#  Index for Google Cloud Next '23 Keynote with Sundar Pichai:
#
# **HTML Code:**
#
# ```html
# <!DOCTYPE html>
# <html
# >
# <head>
#   <title>Google Cloud Next '23 Keynote - Chapter Index</title>
# </head>
# <body>
#
#   <h1>Google Cloud Next '23 Keynote - Chapter Index</h1>
#   <ul>
#     <li><a href="#00:00">Introduction and AI Platform Shift</a></li>
#     <li><a href="#00:20">Announcing Gemini & its capabilities</a
# ></li>
#     <li><a href="#00:35">Introducing Gemini 1.5 Pro</a></li>
#     <li><a href="#01:12">Examples of Gemini in action</a> - Gaming & Insurance</li>
#     <li><a
#  href="#01:49">Customer & Partner Spotlights </a></li>
#     <li><a href="#02:53">Thomas Kurian takes the stage</a></li>
#   </ul>
# </body>
# </html>
# ```
#
# **Explanation:**
#
# *   This code creates a simple HTML page with a title and a heading for the chapter index.
# *   An unordered list (`<ul>`) is
#  used to present each chapter as a list item (`<li>`).
# *   Each chapter title is linked to the corresponding timestamp in the video using the `href` attribute within an anchor tag (`<a>`).
# *   You can easily customize the appearance of the index using CSS styles.
#
# **How to Use:**
#
# 1.  Copy and paste the HTML code into a text editor.
# 2.  Save the file with an `.html` extension (
# e.g., `index.html`).
# 3.  Open the HTML file in a web browser.
# 4.  Click on any chapter title to jump to the specific time in the video.
#
# **Please Note:** This code assumes you are linking to a video hosted online with timestamps enabled. You may need to adjust the links based on your specific video platform and URL structure.
#
# ## Google
#  Cloud Next '23 Chapter Index:
#
# Here's an HTML code for the chapter index with timestamps, assuming each topic mentioned represents a chapter:
#
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Google Cloud Next '23 Chapter Index</title>
#
#   <style>
#     body {
#       font-family: sans-serif;
#     }
#     h1 {
#       text-align: center;
#     }
#     ul {
#       list-style: none;
#       padding: 0;
#     }
#     li {
#
#       margin: 10px 0;
#     }
#     a {
#       text-decoration: none;
#       color: #007bff;
#     }
#   </style>
# </head>
# <body>
#   <h1>Google Cloud Next '23 Chapter Index</h1>
#
#   <ul>
#     <li><a href="#00:00">Introduction & AI Service</a> (00:00)</li>
#     <li><a href="#00:12">Database Enhancements</a> (00:12)</li>
#     <li><a href="#00:24">BigQuery as a Unified Data Analytics Platform</a> (00:24)</li
# >
#     <li><a href="#00:38">Security Products & Chrome Enterprise Premium Browser</a> (00:38)</li>
#     <li><a href="#00:57">Workspace Updates: Security, Extensions & Google Meet</a> (00:57)</li>
#     <li><a href="#01:19">Generative AI & AI Agents</a> (01:
# 19)</li>
#     <li><a href="#02:36">Goldman Sachs & Generative AI</a> (02:36)</li>
#     <li><a href="#04:29">Building with Google Cloud's AI Platform</a> (04:29)</li>
#   </ul>
# </body>
# </html>
# ```
#
# **To use this code:**
#
# 1. **Save** the code as an HTML file (e.g., index.html).
# 2. **Replace** `"#00:00
# "` with the actual video URL and specific time for each chapter.
# 3. **Open** the HTML file in a web browser.
#
# **This will create a simple webpage with clickable links that will take you to the specific timestamp in the video for each chapter.**
#
# ## Google
#  I/O 2023 Keynote Chapter Index:
#
# **00:00 - Introduction:** Sundar Pichai, CEO of Google and Alphabet
# , introduces the keynote and discusses Google's focus on AI innovation.
#
# **00:01 - Google Cloud AI Infrastructure:** Thomas Kurian, CEO
#  of Google Cloud, talks about the comprehensive AI infrastructure offered by Google Cloud, including Vertex AI, and its support for various models.
#
# **00:12 - Vertex AI:**  A deep dive into Vertex AI, a platform for accessing, tuning, managing, and deploying custom models and building AI agents.
#
#
# **00:20 - Gemini for Google Cloud & Workspace:** Introduction of Gemini, a new suite of tools that bring AI capabilities to Google Cloud and Workspace, including code generation and AI agents within Gmail, Docs, and Sheets.
#
# **00:41 - AI Hypercomputer:** Amin Vahdat,
#  VP/GM of ML, Systems and Cloud AI, discusses the AI hypercomputer, Google's infrastructure for training and serving large language models at an unprecedented scale.
#
# **01:19 - Advancements in AI Hypercomputer:** An overview of new enhancements to the AI hypercomputer, including A3 Mega VMs with NVIDIA H100 Tensor Core GPUs and the upcoming NVIDIA GB200 NVL72 GPUs, and the general availability of TPU v5
# p.
#
# **02:24 - AI Optimized Storage:** Introduction of new storage solutions for AI workloads, including Hyperdisk ML, a network-attached block storage optimized for inference and serving.
#
# **03:58 - Open-Source ML Frameworks:** Google's continued optimization of open-source ML frameworks like JAX, PyTorch, and TensorFlow for use with Vertex AI and Google Kubernetes Engine (GKE).
#
# **04:30 - Growth
#  of AI Adoption:** Highlighting the significant growth in the use of GPUs and TPUs on GKE for AI training and inference.
#
# **Please note that the time stamps are approximate and may vary slightly depending on the video version.**
#
# ## HTML Code for Chapter Index:
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Google I/O 2023 Keynote - Chapter Index</title>
#   <style>
#     body {
#       font-family: sans-serif;
#     }
#     h1 {
#       text-align: center;
#
#     }
#     table {
#       width: 80%;
#       margin: 20px auto;
#       border-collapse: collapse;
#     }
#     th, td {
#       border: 1px solid #ddd;
#       padding: 8px;
#       text-align: left;
#     }
#     th {
#       background-color: #f2f2f2;
#     }
#   </style>
# </head>
# <body>
#   <h1>Google I/O 2023 Keynote - Chapter Index</h1>
#   <table>
#     <tr>
#
#       <th>Time Stamp</th>
#       <th>Chapter Title</th>
#     </tr>
#     <tr>
#       <td>00:00</td>
#       <td>Introduction</td>
#     </tr>
#     <tr>
#       <td>00:01</td>
#       <td>Google Cloud AI Infrastructure</td>
#     </tr>
#     <tr>
#       <td>00:12</td>
#       <td>Vertex AI</td>
#     </tr>
#     <tr>
#       <td>00:20</td>
#       <td>Gemini for Google Cloud & Workspace</td>
#     </tr>
#     <tr>
#       <td>00:41</td>
#       <td>AI Hypercomputer</td>
#     </tr>
#
# <tr>
#       <td>01:19</td>
#       <td>Advancements in AI Hypercomputer</td>
#     </tr>
#     <tr>
#       <td>02:24</td>
#       <td>AI Optimized Storage</td>
#     </tr>
#     <tr>
#       <td>03:58</td>
#       <td>Open-Source ML Frameworks</td>
#     </tr>
#     <tr>
#       <td>04:30</td>
#       <td>Growth of AI Adoption</td>
#     </tr>
#   </table>
# </body>
# </html>
# ```
# This code will generate a simple HTML page with a table containing the chapter index. You can customize the styling and
#  formatting as needed.
#
# ## Google
#  Cloud Next '23 Keynote Chapter Index:
#
# **Please note that the timestamps are based on the provided transcript and may not be perfectly aligned with the video.**
#
#
# * **0:00 - 0:09**: Introduction - AI and efficient resource management.
# * **0:09 - 0
# :23**: Dynamic Workload Scheduler - New features: Calendar Mode and Flex Start.
# * **0:23 - 0:32**: AI Hypercomputer Performance and Efficiency.
# * **0:32 - 0:50**: AI Hypercomputer Adoption - Anthropic and Kakao Brain
#  case studies.
# * **0:50 - 1:22**: Bringing AI closer to data - Google Distributed Cloud (GDC) advancements: NVIDIA GPUs, GKE capabilities, Open AI models (Gemma, Llama), Vector Search, and Vertex AI solutions.
# * **1:22 -
#  1:59**: GDC Security and Use Case - Secret and Top Secret accreditations and Orange (mobile provider) case study.
# * **1:59 - 2:23**: Google's history of processor design - TPUs, VCUs, and Tensor processors.
# * **2:23 - 3:35**: Introducing Google Axion Processors - First custom Arm-based CPU for data centers, offering improved performance and energy efficiency
# .
# * **3:35 - 4:15**: Vertex AI Model Garden - Access to over 130 models, including Gemini, partner models (Anthropic's Claude), and open models (Llama, Gemma, Mistral).
# * **4:15 - end**: Gemini 1.5 Pro Public Preview - Processing vast amounts of information with the world's largest context window, enabling cross-modality analysis of audio, video,
#  code, and text.
#
# ## HTML Code for Chapter Index:
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Google Cloud Next '23 Keynote Chapter Index</title>
#   <style>
#     body {
#       font-family: sans-serif;
#     }
#     h1 {
#       text-align: center;
#     }
#     table {
#       width: 80%;
#       margin: 20px auto;
#       border-collapse: collapse;
#     }
#     th, td {
#       border:
#  1px solid #ccc;
#       padding: 8px;
#       text-align: left;
#     }
#   </style>
# </head>
# <body>
#   <h1>Google Cloud Next '23 Keynote Chapter Index</h1>
#   <table>
#     <thead>
#       <tr>
#         <th>Timestamp</th>
#         <th>Topic</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td>0:00 - 0:09</td>
#         <td>Introduction - AI and efficient resource management</td>
#       </tr>
#       <tr>
#         <td>0:09 - 0:23</td>
#
#         <td>Dynamic Workload Scheduler - New features: Calendar Mode and Flex Start</td>
#       </tr>
#       <tr>
#         <td>0:23 - 0:32</td>
#         <td>AI Hypercomputer Performance and Efficiency</td>
#       </tr>
#       <tr>
#         <td>0:32 - 0:50</td>
#         <td>AI Hypercomputer Adoption - Anthropic and Kakao Brain case studies</td>
#       </tr>
#       <tr>
#         <td>0:50 - 1:22</td>
#         <td>Bringing AI closer to data - GDC advancements</td>
#       </tr>
#       <tr>
#         <td>1:
# 22 - 1:59</td>
#         <td>GDC Security and Use Case</td>
#       </tr>
#       <tr>
#         <td>1:59 - 2:23</td>
#         <td>Google's history of processor design</td>
#       </tr>
#       <tr>
#         <td>2:23 - 3:35</td>
#         <td>Introducing Google Axion Processors</td>
#       </tr>
#       <tr>
#         <td>3:35 - 4:15</td>
#         <td>Vertex AI Model Garden - Access to over 130 models</td>
#       </tr>
#       <tr>
#         <td>4:1
# 5 - end</td>
#         <td>Gemini 1.5 Pro Public Preview - Cross-modality analysis</td>
#       </tr>
#     </tbody>
#   </table>
# </body>
# </html>
# ```
#
# **This HTML code will create a simple table with two columns: Timestamp and Topic. You can easily copy and paste this code into an HTML file and open it in a web browser to view the chapter index.**
#
# ## Chapter
#  Index for Google Cloud Next '23 Keynote with Sundar Pichai:
#
# **Please note that the timestamps are approximate and based on the information provided. You
#  may need to adjust them based on the actual video.**
#
# **0:00 - Introduction:** Sundar Pichai welcomes the audience and introduces the theme of
#  the keynote: advancements in AI and its applications.
#
# **0:05 - Large Language Models and the Power of Context Window:**  Sundar Pichai discusses the capabilities of large language models (LLMs) and how Google is leveraging the context window to enhance user experience and extract valuable insights from data.
#
#
# **0:19 - Examples of LLM Applications:**
# * **University Professor:** Extracting data from a 3,000-page document with text, data tables, and charts.
# * **Financial Services Company:** Searching, analyzing, understanding, and answering questions on complex merger and acquisition documents
# .
# * **Startup Founder:** Understanding codebases to identify critical issues and implement fixes.
# * **Sports Technology Company:** Using AI-enabled cameras to evaluate plays and find key moments in sports videos.
#
# **1:04 - Claude 3 Announcement:**  Sundar Pichai announces the general availability of Claude 3, a state-of-the-art language model from Anthropic, on Vertex AI.
#
# **1:20 - Codey
#  Announcement:** Introduction of Codey, a fine-tuned, lightweight open model designed for coding and built with the same technology used to create Gemini.
#
# **1:31 - Vertex AI Capabilities:**
# * **Model Tuning and Customization:** Vertex AI provides various techniques like fine-tuning, reinforcement learning, and distillation to customize LLMs.
# * **Grounding Results:** Combining retrieval and generative models to provide high-quality, personalized answers and recommendations.
# * **
# Connecting Models with Enterprise Data:** Using extensions and function calling to integrate models with enterprise applications and databases.
# * **Model Management and Monitoring:** Utilizing Vertex AI's MLOps tools to manage and monitor models effectively.
#
# **2:55 - Grounding with Google Search:** Announcement of the integration with Google Search to improve response quality and reduce hallucinations in LLM outputs.
#
# **3:26 - Grounding with Enterprise Data:** Introducing the ability to ground models with data from enterprise databases and applications, including AlloyDB and BigQuery, and any database.
#
# **3:53 - Prompt Management:**  Announcing
#  new prompt management tools to help developers collaborate, track changes, compare response quality, and improve prompts.
#
# **4:25 - Rapid Evaluation:** Introduction of the rapid evaluation feature (in preview) for quickly evaluating models with smaller datasets.
#
# **4:31 - Generali Italia Case Study:**  Showcasing how Generali Italia used Vertex AI to build a model evaluation pipeline and improve model deployment efficiency.
#
# **4:48 - Partner Application Integrations:** Highlighting integrations with various partners, including Hugging Face, GitLab, Replit, Salesforce, SAP, and VS Code, to facilitate access to LLMs
#  and other models on Vertex AI.
#
#
# ## HTML Code for Presenting the Chapter Index:
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Google Cloud Next '23 Keynote Chapter Index</title>
#   <style>
#     body {
#       font-family: sans-serif;
#     }
#     h1 {
#       text-align: center;
#     }
#     table {
#       width: 100%;
#       border-collapse: collapse;
#     }
#     th, td {
#       border: 1px solid black;
#
#       padding: 8px;
#       text-align: left;
#     }
#   </style>
# </head>
# <body>
#   <h1>Google Cloud Next '23 Keynote Chapter Index</h1>
#   <table>
#     <tr>
#       <th>Timestamp</th>
#       <th>Chapter Title</th>
#     </tr>
#     <tr>
#       <td>0:00</td>
#       <td>Introduction</td>
#     </tr>
#     <tr>
#       <td>0:05</td>
#       <td>Large Language Models and the Power of Context Window</td>
#     </tr>
#     <tr>
#       <td>0:19</td>
#       <td>Examples of L
# LM Applications</td>
#     </tr>
#     <!-- Add remaining chapters here -->
#     <tr>
#       <td>4:48</td>
#       <td>Partner Application Integrations</td>
#     </tr>
#   </table>
# </body>
# </html>
# ```
#
# **Please note that you will need to add the remaining chapters to the table within the HTML code, following the same format as the provided examples.**
#
# ## Chapter
#  Index for Video:
#
# **Please note that I cannot analyze the video content and generate timestamps without further information. However, based on the transcript you provided, I
#  can suggest the following chapter titles and a possible HTML structure for your index:**
#
# **Chapters:**
#
# 1. **Vertex AI: A unified platform for AI development
# ** (0:00 - 0:13)
# 2. **Types of AI Agents:** (0:23 - )
#     * **2.1 Customer Agents: Enhancing customer experiences** (0:26 - 0:33)
#     * **2.2 Mercedes
# -Benz and Customer Agents: A case study** (1:00 - 4:03)
#     * **2.3 Samsung Galaxy S24 and Generative AI Features** (4:16 - 4:33)
#     * **2.4 Intercontinental Hotels Group
# : AI-powered travel planning** (4:51 - 5:01)
#     * **2.5 More Examples: ADT, Fox Sports, Canva** (5:01 - )
#
# **HTML Code:**
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Video Chapter Index</title>
#   <style>
#     /* Add your desired styling here */
#   </style>
#
# </head>
# <body>
#   <h1>Video Chapter Index</h1>
#   <ol>
#     <li>
#       <a href="#0:00">Vertex AI: A unified platform for AI development</a>
#     </li>
#     <li>
#       Types of AI Agents:
#       <ol>
#         <li><a href="#0:26">Customer Agents: Enhancing customer experiences</a></li>
#         <
# li><a href="#1:00">Mercedes-Benz and Customer Agents: A case study</a></li>
#         <li><a href="#4:16">Samsung Galaxy S24 and Generative AI Features</a></li>
#         <li><a href="#4:51">Intercontinental Hotels Group: AI-powered travel planning</a></li>
#         <li><a href="#5:01">More Examples: ADT, Fox Sports, Canva</a></li>
#       </ol>
#     </li>
#   </ol>
# </body>
#
# </html>
# ```
#
# **Implementation Tips:**
#
# * **Timestamps:** Replace the `#0:00` placeholders with the actual timestamps once you have identified them in the video.
# * **Styling:** Add CSS rules within the `<style>` tags to customize the appearance of your index.
# * **Linking:** Ensure the links accurately point to the corresponding sections in your video.
# * **Additional Chapters:** Modify the HTML structure to accommodate additional chapters and sub-chapters as needed.
#
# **I hope this helps! Let me know if you have any other questions.**
#
# ## Chapter
#  Index for Google I/O 2023 Keynote with Sundar Pichai:
#
# **I.  Introduction & Generative AI Applications:**
# *
#  **00:00:** Sundar Pichai introduces the focus on generative AI and its transformative potential.
# * **00:01 -
#  00:19:** Showcase of various companies using generative AI to enhance customer experiences and services:
#     * **ADT:**  An AI agent for home security system selection and setup.
#     * **Verizon:**  Improved agent recommendations in call centers.
#     * **Magalu:**  Generative
#  AI at the core of customer service for a Brazilian retailer.
#     * **ING:**  A chatbot to enhance self-service and improve answer quality.
#     * **Target:** Personalized offers within the Target app and website.
#     * **Minnesota’s Department of Public Safety:** Real-time translation for non
# -English speakers seeking licenses and services.
#     * **Best Buy:**  An AI assistant for troubleshooting tech issues, managing deliveries, and software.
#     * **Discover:**  Research and synthesis across policies and procedures during customer service calls.
#     * **Orange:**  A French language agent grounded in support knowledge, transforming customer experience at contact sites.
#     * **Oppo & OnePlus:**  Incorporation of PaLM API and Google Cloud AI into smartphones for innovative
#  customer experiences including news, audio summaries, AI toolbox, and more.
#
# **II.  Vertex AI Agent Builder:**
# * **01:43:** Introduction of Vertex AI Agent Builder as a tool to accelerate and simplify customer agent creation.
# * **01:49 - 03:16:** Three key steps for building powerful customer agents:
#     * **Human-like Conversations:**  Utilize PaLM API for free-flowing, natural
#  language interactions across text, voice, images, and video.
#     * **Control & Shape Conversations:**  Guide conversation flow and restrict topics using natural language instructions.
#     * **Ground Responses & Improve Quality:** Enhance response quality through vector-based and keyword-based search, connecting to internal information and the web.  Integrate with enterprise databases (AlloyDB), predictive analytics (BigQuery), and SaaS applications (ServiceNow)
#
# **III.  Customer Agent Demo:**
# * **03:26:** Amanda Lewis demonstrates a customer agent in action on the "Symbol Fashion" website.
# * **03:3
# 1 - 04:59:** Amanda interacts with the agent to search for a specific checkered shirt seen in a video, showcasing the agent's ability to understand complex requests and provide relevant information.
#
# **Note:** This index provides a high-level overview of the video content based on the transcript and screenshots provided. It may not capture every detail or nuance of the presentation.
#
# ## Chapter
#  Index for Video:
#
# **Please note that I lack timestamps for specific sections within the video. You'll need to add those based on the actual video content
# .**
#
# *   **Introduction:** Overview of Google Cloud's AI capabilities and the concept of AI Agents.
# *   **Customer Agent Demo:** Showcase of
#  Cymbal Fashion's customer service agent powered by Google Cloud AI, demonstrating features such as product recommendations, inventory checks, and purchase processing.
# *   **Behind the Scenes:** Explanation of how Cymbal Fashion's customer agent leverages Google Cloud's AI suite, including search technologies and historical data, to provide
#  personalized and efficient support interactions.
# *   **Employee Agents:** Discussion of how companies like Uber are using Google Cloud AI to build employee agents for improved productivity, collaboration, and cost reduction.
# *   **Uber's Use Case:** Interview with Uber CEO Dara Khosrowshahi discussing their partnership with Google Cloud
#  and the utilization of AI tools like Gemini for workspace efficiency and AI agent development for customer support.
#
# ## HTML Code for Presenting Chapter Index:
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Video Chapter Index</title>
# <style>
# body {
#   font-family: sans-serif;
# }
# h2 {
#   color: #333;
# }
# ul {
#   list-style
# : none;
#   padding: 0;
# }
# li {
#   margin: 10px 0;
# }
# a {
#   color: #007bff;
#   text-decoration: none;
# }
# </style>
# </head>
# <body>
# <h2>Video Chapter Index</h2>
# <ul>
#   <li><a href="#intro">Introduction</a></li>
#   <li><a href
# ="#customer-agent">Customer Agent Demo</a></li>
#   <li><a href="#behind-scenes">Behind the Scenes</a></li>
#   <li><a href="#employee-agents">Employee Agents</a></li>
#   <li><a href="#uber">Uber's Use Case</a></li>
# </ul>
#
# <h3 id="intro">Introduction</h3>
# <p>This section provides an overview of...</p>
#
# <h3 id="customer-agent">Customer Agent Demo</h3>
# <p>This section showcases a demonstration of...</p>
#
# <
# h3 id="behind-scenes">Behind the Scenes</h3>
# <p>This section explains how...</p>
#
# <h3 id="employee-agents">Employee Agents</h3>
# <p>This section discusses how companies like Uber are using...</p>
#
# <h3 id="uber">Uber's Use Case</h3>
# <p>This section features an interview with Uber CEO Dara Khosrowshahi...</p>
#
# </body>
# </html>
# ```
#
# **Please note:**
#
# *   Replace the placeholder text under each chapter heading with a brief description of the content.
# *   You'll
#  need to add the specific timestamps within each chapter section.
# *   This code assumes you will be embedding the video on the same page as the index. You can adjust the code to link to a separate video page if needed.
#
# ## Chapter
#  Index for Google I/O 2023 Keynote with Aparna Pappu:
#
# **HTML code for presenting the chapter index:**
#
# ```html
#
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Google I/O 2023 Keynote - Aparna Pappu
# </title>
#   <style>
#     body { font-family: sans-serif; }
#     h2 { color: #DB4437; }
#     ul { list-style: none; padding: 0; }
#     li { margin: 10px 0
# ; }
#     a { text-decoration: none; color: #4285F4; }
#   </style>
# </head>
# <body>
#   <h2>Google I/O 2023 Keynote - Aparna Pappu</h2>
#   <ul>
#     <li
# ><a href="#intro">00:00 - Introduction: Empowering work and customers with AI</a></li>
#     <li><a href="#gemini-overview">00:30 - Introducing Gemini for Google Workspace</a></li>
#     <li><a href="#customer-stories">01:30 - Customer stories: Pepperdine University, PennyMac, Woolworths</a></li>
#     <li><a href
# ="#ai-add-ons">02:10 - Announcing AI add-ons for Workspace</a></li>
#     <li><a href="#meetings-messaging">02:50 - AI Meetings and Messaging add-on</a></li>
#     <li><a href="#security">03:10 - AI Security add-on</a></li>
#     <li><a href="#chat-preview">03
# :25 - Gemini in Google Chat (Preview)</a></li>
#     <li><a href="#demo">03:43 - Demonstration: Evaluating proposals with Gemini</a></li>
#   </ul>
#   <hr>
#
#   <h3 id="intro">00:00 - Introduction: Empowering work and customers with AI</h3>
#   <p>Dara Khosrowshahi, CEO of Uber, discusses how Google Cloud helps Uber create new ways to empower their workforce and better serve customers through AI.</p>
#
#   <h3 id="gemini-overview">0
# 0:30 - Introducing Gemini for Google Workspace</h3>
#   <p>Aparna Pappu introduces Gemini for Google Workspace, an AI-powered agent integrated within Gmail, Docs, Sheets, and more. She highlights its capabilities as a research partner, notetaker, and creative collaborator.</p>
#
#   <h3 id="customer-stories">01:30 - Customer stories: Pepperdine University, PennyMac, Woolworths</h3>
#   <p>Aparna shares how various companies benefit from Gemini for Google Workspace:</p>
#   <ul>
#     <li>Pepperdine University uses real-time translated
#  captioning and notes for multilingual meetings.</li>
#     <li>PennyMac utilizes AI for recruiting, hiring, and employee onboarding.</li>
#     <li>Woolworths seeks to unlock team productivity for its administrative employees.</li>
#   </ul>
#
#   <h3 id="ai-add-ons">02:10 - Announcing AI add-ons for Workspace</h3>
#   <p>Aparna announces the launch of new AI add-ons to further enhance productivity and security within Google Workspace.</p>
#
#   <h3 id="meetings-messaging">02:50 - AI
#  Meetings and Messaging add-on</h3>
#   <p>This add-on provides features like "take notes for me," chat summarization, and real-time translation for a cost of $10 per user per month.</p>
#
#   <h3 id="security">03:10 - AI Security add-on</h3>
#   <p>This add-on empowers Workspace admins to automatically classify and protect sensitive files and data using privacy-preserving AI models trained for their organization.</p>
#
#   <h3 id="chat-preview">03:25 - Gemini in Google Chat (Preview)</h3>
#
#   <p>Gemini can now participate in Google Chat conversations, summarizing threads, decisions, and acting as a real-time creative partner.</p>
#
#   <h3 id="demo">03:43 - Demonstration: Evaluating proposals with Gemini</h3>
#   <p>Kristina Behr, Product Lead for Workspace Collaboration Apps, demonstrates how Gemini for Google Workspace helps users efficiently compare proposals and extract key information, saving time and effort.</p>
#
# </body>
# </html>
# ```
#
# **Note:** This HTML code provides a basic structure with anchor links to each chapter. You can further customize it by adding CSS styling
#  for visual appeal and additional information about each chapter.
#
# ## Chapter
#  Index for Google Cloud Next '23 Keynote with HTML Code
#
# Unfortunately, I cannot directly access and process video content to create a chapter index. However, based
#  on the information you've provided, I can offer a possible structure and the corresponding HTML code to present it.
#
# **Possible Chapter Index:**
#
# 1.
#  **Introduction to Google Cloud Next '23**
# 2. **Vertex AI & Generative AI advancements**
#     *   Overview of Vertex AI features
#     *   Demo: Using Gemini in Google Docs for compliance checks
# 3. **Employee Agents powered by Vertex AI**
#     *   Customer Use Cases:
#
#         *   Bristol Myers Squibb: Streamlining clinical trial documents
#         *   Dasa: Detecting findings in medical test results
#         *   Sutherland: Enhancing customer service
#         *   HCA Healthcare: Reducing caregiver paperwork
#         *   Victoria's Secret & Co: Providing personalized recommendations
#
#         *   The Home Depot: Managing inventory and stock
#         *   Etsy: Optimizing ad models and search
#     *   Vertex AI features for employee agents:
#         *   Custom models
#         *   Multi-modal inputs
#         *   Grounding and extensions
#         *   Add-on framework
#     *   Demo: Employee agent in action
# 4. **Other Announcements and Keynotes** (Depending on the video content)
# 5.
#  **Conclusion and Next Steps**
#
# **HTML Code:**
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Google Cloud Next '23 Keynote - Chapter Index</title>
#   <style>
#     body { font-family: sans-serif; }
#     h2 { color: #007bff; } /* Example color, change as needed */
#     ul { list-style: none; padding
# : 0; }
#     li { margin: 5px 0; }
#     a { text-decoration: none; color: #333; }
#     a:hover { color: #007bff; } /* Example color, change as needed */
#   </style>
# </head>
# <body>
#   <h1>Google Cloud Next '23 Keynote - Chapter Index</h1>
#
#   <h2>1. Introduction to Google Cloud Next '23</h2>
#
#   <h2>2. Vertex AI & Generative AI advancements</h2>
#   <ul>
#     <li><a
#  href="#vertex-features">Overview of Vertex AI features</a></li>
#     <li><a href="#gemini-demo">Demo: Using Gemini in Google Docs for compliance checks</a></li>
#   </ul>
#
#   <h2>3. Employee Agents powered by Vertex AI</h2>
#   <ul>
#     <li>Customer Use Cases:</li>
#     <ul>
#       <li><a href="#bristol-myers">Bristol Myers Squibb: Streamlining clinical trial documents</a></li>
#       <li><a href="#dasa">Dasa: Detecting
#  findings in medical test results</a></li>
#       <li><a href="#sutherland">Sutherland: Enhancing customer service</a></li>
#       <li><a href="#hca">HCA Healthcare: Reducing caregiver paperwork </a></li>
#       <li><a href="#victorias-secret">Victoria's Secret & Co: Providing personalized recommendations</a></li>
#       <li><a href="#home-depot">The Home Depot: Managing inventory and stock</a></li>
#       <li><a href="#etsy">Etsy: Optimizing ad models and search</a
# ></li>
#     </ul>
#     <li>Vertex AI features for employee agents:</li>
#     <ul>
#       <li><a href="#custom-models">Custom models</a></li>
#       <li><a href="#multi-modal">Multi-modal inputs</a></li>
#       <li><a href="#grounding">Grounding and extensions</a></li>
#       <li><a href="#add-on">Add-on framework</a></li>
#     </ul>
#     <li><a href="#employee-agent-demo">Demo
# : Employee agent in action</a></li>
#   </ul>
#
#   <h2>4. Other Announcements and Keynotes</h2>
#   <!-- Add specific topics and links as needed -->
#
#   <h2>5. Conclusion and Next Steps</h2>
#
# </body>
# </html>
# ```
#
# **Please note:**
#
# *   You will need to replace `#vertex-features`, `#gemini-demo`, etc. with the actual timestamps or IDs in your video platform for each chapter.
# *   You can adjust the styling and add more chapters or details as necessary.
#
# I hope this provides
#  a helpful starting point for creating your chapter index! Let me know if you have any other questions.
#
# ## Chapter
#  Index and HTML Code for "2024 Open Enrollment" Video
#
# Unfortunately, I cannot directly process and analyze video content to create a chapter index.
#  However, I can provide you with a template and guide you through the process of creating a chapter index and the corresponding HTML code to present it.
#
# **
# Creating the Chapter Index:**
#
# 1. **Watch the video:**  Take notes on key topics, transitions, and timestamps where significant new information is introduced.
# 2. **Identify Chapters:**  Group related topics and transitions into chapters. Aim for logical flow and coherence.
# 3. **Assign Titles and Timestamps
# :**  Give each chapter a concise and descriptive title that reflects its content. Note the starting timestamp for each chapter.
#
# **Example Chapter Index:**
#
# ```
# * **Introduction (00:00):** Open enrollment overview and importance.
# * **Understanding Your Needs (03:15):**
#  Assessing healthcare needs and plan options.
# * **Exploring Plan Options (10:45):** Comparing premiums, deductibles, and coverage options (HMO, PPO, HDHP).
# * **Flexible Spending Accounts (FSAs) (22:00):** Deciding on FSA or HSA contributions.
# * **Additional Benefits (35:20):** Dental, vision, life, and disability insurance options.
# * **Enrollment and Next
#  Steps (42:10):**  Navigating the benefits portal, making selections, and deadlines.
#
# ```
#
# **Generating the HTML Code:**
#
# 1. **Choose a Structure:**  Decide on the layout for your index (e.g., ordered list, unordered list, table).
# 2. **Use HTML tags:**  Employ appropriate HTML tags to structure your index (e.g., `<ol>`, `<ul>`, `<table>`, `
# <tr>`, `<td>`, `<a>`).
# 3. **Link Timestamps:**  Utilize the `<a>` tag with the `href` attribute to link chapter titles to their corresponding timestamps in the video.
#
# **Example HTML Code (using an unordered list):**
#
# ```html
# <ul>
#   <li><a href="https://yourvideo.com/#t=0">Introduction (00:00)</a></li>
#   <li><a href="https://yourvideo.com/#t=195">Understanding Your Needs (03:15)</a
# ></li>
#   <li><a href="https://yourvideo.com/#t=645">Exploring Plan Options (10:45)</a></li>
#   <li><a href="https://yourvideo.com/#t=1320">Flexible Spending Accounts (FSAs) (22:00)</a></li>
#   <li><a href="https://yourvideo.com/#t=2120">Additional Benefits (35:20)</a></li>
#   <li><a href="https://yourvideo.com/#
# t=2530">Enrollment and Next Steps (42:10)</a></li>
# </ul>
# ```
#
# **Additional Considerations:**
#
# * **Styling:**  Use CSS to customize the appearance of your chapter index (font, color, spacing, etc.)
# * **Interactive elements:**  You can incorporate JavaScript for interactive features, like expanding/collapsing chapters.
# * **Video platform integration:**  Check if your video platform offers built-in chaptering functionality.
#
#
# **By following these steps and adapting the examples to your specific video content, you can create a user-friendly and informative
#  chapter index using HTML.**
#
# ## Chapter
#  Index for Google Vids Presentation with HTML Code:
#
# **Please note that I cannot access external websites or specific files, including the video you mentioned. Therefore,
#  I've created a general chapter index based on the information you provided. You can easily adapt it to your specific content and timestamps.**
#
# **Chapter Index
# :**
#
# 1. **Introduction (00:00 - 00:09):** Setting the stage for the presentation and introducing the concept of generative AI agents.
# 2. **Employee Agents (00:09 - 00:09):** Briefly showcasing the capabilities of employee agents
#  like scheduling reminders.
# 3. **Creative Agents (00:09 - 02:53):**
#     * **Overview (00:09 - 00:34):** Highlighting the role of generative AI in content creation, personalization, and campaign adjustments.
#
#     * **Carrefour Case Study (00:34 - 01:19):** Demonstrating how Carrefour utilizes Vertex AI for streamlined campaign creation and personalized advertising.
#     * **Canva Case Study (01:19 - 01:34):**  Showcasing Canva's use of Vertex AI in its Magic Design tool for video editing, simplifying the process for users.
#     * **P&G Case Study (0
# 1:34 - 02:17):**  Explaining how P&G leverages Vertex AI to generate photo-realistic images and creative assets, enhancing team efficiency and media budget optimization.
#     * **WPP Case Study (02:17 - 02:53):**  Presenting WPP's performance brain tool utilizing Gemini 1.5 Pro on Vertex AI for predicting ad performance and minimizing media waste.
# 4
# . **Introducing Google Vids (02:53 - 03:15):**  Announcing the new AI-powered video creation app for Google Workspace.
# 5. **Google Vids Demo (03:15 - 04:41):**
#     * **Getting Started (03:15 - 03:34):** Demonstrating the ease of use by providing a prompt and selecting a document for context.
#     * **Narrative Outline Generation (03:34 - 03:43):**  Showcasing the AI-
# generated narrative outline based on the provided prompt and document.
#     * **Style Selection (04:43 - 03:48):** Choosing an appropriate style for the video.
#     * **Video Creation (03:48 - 04:19):**  Highlighting the automatic generation of scenes with relevant stock media and music, along with a generated script.
#     * **Personalization Options (04:19 - 04:41):**  Explaining how users can personalize their videos by recording themselves or utilizing preset voices by Gemini, and by enriching scenes
#  with their own media.
# 6. **Collaboration and Benefits (04:41 - 05:00):**
#     * **Collaboration Features (04:41 - 04:49):**  Emphasizing the built-in collaboration capabilities within Google Vids as part of Google Workspace.
#     * **Empowering Storytelling (04:49 - 05:00):**  Concluding with the potential of Google Vids to empower users in becoming better storytellers and utilizing the power of video effectively.
#
# **HTML Code:**
#
# ```html
#
# <!DOCTYPE html>
# <html>
# <head>
# <title>Google Vids Presentation - Chapter Index</title>
# <style>
# body {font-family: sans-serif;}
# h2 {color: #336699;}
# ul {list-style: none; padding: 0;}
# li {margin: 10px 0;}
# a {text-decoration: none; color: #0000EE;}
# a:hover {text-decoration: underline;}
# </style>
# </head>
# <body>
# <h2>Chapter Index</h2>
#
# <ul>
#   <li><a href="#intro">Introduction (00:00 - 00:09)</a></li>
#   <li><a href="#employee">Employee Agents (00:09 - 00:09)</a></li>
#   <li>
#     <a href="#creative">Creative Agents (00:09 - 02:53)</a>
#     <ul>
#       <li><a href="#overview">Overview (00:09 - 00:34)</a></li>
#
#       <li><a href="#carrefour">Carrefour Case Study (00:34 - 01:19)</a></li>
#       <li><a href="#canva">Canva Case Study (01:19 - 01:34)</a></li>
#       <li><a href="#pg">P&G Case Study (01:34 - 02:17)</a></li>
#       <li><a href="#wpp">WPP Case Study (02:17 - 02:53)</a
# ></li>
#     </ul>
#   </li>
#   <li><a href="#vids">Introducing Google Vids (02:53 - 03:15)</a></li>
#   <li>
#     <a href="#demo">Google Vids Demo (03:15 - 04:41)</a>
#     <ul>
#       <li><a href="#start">Getting Started (03:15 - 03:34)</a></li>
#       <li><a href="#outline">Narrative Outline Generation (
# 03:34 - 03:43)</a></li>
#       <li><a href="#style">Style Selection (04:43 - 03:48)</a></li>
#       <li><a href="#creation">Video Creation (03:48 - 04:19)</a></li>
#       <li><a href="#personalize">Personalization Options (04:19 - 04:41)</a></li>
#     </ul>
#   </li>
#   <li>
#     <a
#  href="#benefits">Collaboration and Benefits (04:41 - 05:00)</a>
#     <ul>
#       <li><a href="#collab">Collaboration Features (04:41 - 04:49)</a></li>
#       <li><a href="#storytelling">Empowering Storytelling (04:49 - 05:00)</a></li>
#     </ul>
#   </li>
# </ul>
# </body>
# </html>
# ```
#
# **This HTML code provides a basic structure for your chapter index
# . You'll need to replace the "#intro", "#employee", etc. with the actual IDs of the corresponding sections in your video or presentation.**
#
# ## Chapter
#  Index for Google AI Presentation
#
# Based on the information provided, here's a possible chapter index for the video along with the HTML code to present it:
#
#
# **HTML Code:**
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Chapter Index</title>
#
#   <style>
#     body {
#       font-family: sans-serif;
#     }
#     .chapter {
#       margin-bottom: 10px;
#     }
#     .time {
#       color: #999;
#     }
#   </style>
#
# </head>
# <body>
#   <h1>Chapter Index</h1>
#   <div class="chapter">
#     <span class="time">00:00</span> - Introduction to Google Vids
#   </div>
#   <div class="chapter">
#     <span class="time">
# 00:20</span> - Building Creative Agents with Vertex AI
#   </div>
#   <div class="chapter">
#     <span class="time">00:40</span> - Imagen 2.0: Text-to-Image Generation
#   </div>
#   <div class="chapter">
#     <span class="time">01:15</span> - Text-to-Live Image (Preview)
#
#   </div>
#   <div class="chapter">
#     <span class="time">01:53</span> - Digital Watermarking for AI Images
#   </div>
#   <div class="chapter">
#     <span class="time">02:04</span> - New Editing Modes in Imagen 2.0
#   </div>
#   <div class="chapter">
#     <span class="time">
# 02:36</span> - Creative Agent Demo with Cymbal Outfitters
#   </div>
# </body>
# </html>
# ```
#
# **Explanation of the code:**
#
# *   The code uses basic HTML structure with a title and a heading.
# *   Each chapter is enclosed within a `div` with the class `chapter`.
# *   The time stamp for each chapter is enclosed within a `span` with the class `time`.
# *   Basic CSS styling is used to improve readability. You can further customize the styles to match your preferences.
#
# **To use the code:**
#
#
# 1.  Copy and paste the code into a text editor.
# 2.  Save the file with an `.html` extension.
# 3.  Open the file in a web browser to view the chapter index.
#
# ## Chapter
#  Index for Cymbal Outfitters Video:
#
# **00:00 - 00:09**  Introduction: Creative Agent leverages Gemini Pro
#  for multilingual caption generation.
# **00:10 - 00:19**  Multilingual Capabilities: Sharing stories with customers in their
#  native languages.
# **00:20 - 00:37**  Storyboard Generation and Sharing: Generating a storyboard and exporting it to Google Slides for team feedback.
# **00:38 - 00:59**  Team Feedback and New Storyboard:  Reviewing
#  feedback and generating a new storyboard for a relaxed camping theme.
# **01:00 - 01:29**  Podcast Script and Audio Generation: Creating a podcast script with SSML and generating an audio clip using text-to-speech.
# **01:30 - 02
# :37**  Live Image Generation for Social Media:  Generating visually dynamic content using Imagen for social media.
# **02:38 - End**  Walmart and Data Agents:  Suresh Kumar, EVP and CTO of Walmart, discusses the use of data and AI.
#
# ## HTML Code for Chapter Index:
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Cymbal Outfitters Video Chapter Index
# </title>
#   <style>
#     body {
#       font-family: sans-serif;
#     }
#     h1 {
#       text-align: center;
#     }
#     table {
#       width: 80%;
#       margin: 20px auto;
#       border-collapse: collapse;
#     }
#     th, td {
#       border: 1px solid #ddd;
#       padding:
# 8px;
#       text-align: left;
#     }
#     th {
#       background-color: #f2f2f2;
#     }
#   </style>
# </head>
# <body>
#   <h1>Cymbal Outfitters Video Chapter Index</h1>
#   <table>
#     <tr>
#       <th>Time</th>
#       <th>Chapter Title</th>
#     </tr>
#     <tr>
#       <td>00:00 - 00:09</td>
#       <td>Introduction: Multilingual Caption Generation</td>
#     </tr>
#     <tr>
#       <td>00:10 - 00:1
# 9</td>
#       <td>Sharing Stories in Native Languages</td>
#     </tr>
#     <tr>
#       <td>00:20 - 00:37</td>
#       <td>Storyboard Generation and Team Feedback</td>
#     </tr>
#     <tr>
#       <td>00:38 - 00:59</td>
#       <td>New Storyboard for Relaxed Camping</td>
#     </tr>
#     <tr>
#       <td>01:00 - 01:29</td>
#       <td>Podcast Script and Audio Generation</td>
#     </tr>
#     <tr>
#       <td>01:30 - 02:37</td>
#
#       <td>Live Image Generation for Social Media</td>
#     </tr>
#     <tr>
#       <td>02:38 - End</td>
#       <td>Walmart and Data Agents</td>
#     </tr>
#   </table>
# </body>
# </html>
# ```
#
# **This code will create a simple, clean table with two columns: one for the time stamp and one for the chapter title. You can customize the styling and add additional information as needed.**
#
# ## Chapter
#  Index for Google Cloud Next '23 Video: Data Agents
#
# While I cannot directly generate HTML code, I can provide you with the structure and content for the
#  chapter index, which you can then easily translate into HTML using appropriate tags and formatting.
#
# **Chapter Index**
#
# *   **00:00 -
#  00:30:** Introduction by Suresh Kumar, EVP & Chief Technology and Development Officer, Walmart
# *   **00:30 - 02:30:** Overview of Data Agents and their potential, with examples of how companies like Bayer, News Corp, Woven by Toyota, Mercado Libre,
#  Mayo Clinic, Tokopedia, and Vodafone are using Vertex AI and BigQuery
# *   **02:30 - 04:00:** Introduction to new BigQuery capabilities:
#     *   Gemini in BigQuery: Simplifying data preparation using AI
#     *   Vector Indexing in BigQuery and
#  AlloyDB: Querying the right data in analytical and operational systems
#     *   BigQuery Data Canvas: Notebook-like experience with natural language and embedded visualizations
#     *   Direct Access to Vertex AI from BigQuery: Access and analyze documents, videos, images, and audio with your data
# *   **04:00 - 04:56:** Introduction to Gemini in Looker: Chat with your business data through seamless integration with Google Workspace
#
# **
# HTML Structure (Example):**
#
# ```html
# <h1>Chapter Index</h1>
# <ol>
#   <li><a href="#00:00">Introduction by Suresh Kumar</a></li>
#   <li><a href="#00:30">Data Agents Overview and Examples</a></li>
#   <li>
#     <a href="#02:30">New BigQuery Capabilities</a>
#     <ul>
#
# <li><a href="#gemini-bq">Gemini in BigQuery</a></li>
#       <li><a href="#vector-indexing">Vector Indexing</a></li>
#       <li><a href="#data-canvas">BigQuery Data Canvas</a></li>
#       <li><a href="#direct-access">Direct Access to Vertex AI</a></li>
#     </ul>
#   </li>
#   <li><a href="#04:00">Gemini in Looker</a></li>
# </ol>
# ```
#
# **Remember to replace the href links
#  with the actual timestamps or video chapter links for navigation.**
#
# **Additional Considerations:**
#
# *   You can use CSS to style the chapter index and make it visually appealing.
# *   Consider adding a brief description of each chapter under its title for better context.
# *   If the video is long, you might want to divide the chapters into sections for better organization.
#
# ## Chapter
#  Index for Video:
#
# (Please note, I cannot access and process the video content to create specific timestamps and titles. However, I can provide a general
#  structure based on the transcript you provided. You would need to fill in the specific details)
#
# **Chapter 1: Introduction (00:00 -
#  00:19)**
# * Briefly introduce the speaker and the topic of the video.
# * Highlight the main focus on data analysis and AI.
#
# **Chapter 2: Data Agent Overview (00:23 - 01:13)**
# * Explain the concept of the Data Agent
#  and its function.
# * Describe the use of real-time KPIs and BigQuery for data monitoring.
# * Emphasize the role of the Looker semantic layer in providing trusted data and insights.
#
# **Chapter 3: Analyzing Sales Trends (01:14 - 02:09)**
#
# * Explore the sales spike for Cloud Shoes.
# *  Investigate the impact of customer segments and territories on the trend.
# * Discuss the importance of data details for source and traceability.
#
# **Chapter 4: Supply and Demand Forecast (02:10 - 02:24)**
# * Analyze projected supply levels compared to demand using BigQuery machine learning.
# * Identify the gap between supply and demand for Cloud Shoes.
# * Discuss the need
#  for substitute products to meet demand.
#
# **Chapter 5: Similar Product Search (02:25 - 03:13)**
# * Utilize BigQuery vector embeddings to find similar products in the catalog.
# * Upload an image of Cloud Shoes and retrieve top matches based on visual similarity.
# * Combine image search results with structured data on pricing and delivery schedules.
#
# **Chapter 6: Actionable Insights and Collaboration (03:14
#  - 04:11)**
# * Share the insights and search results with the inventory team through Looker and Workspace integration.
# * Emphasize the ease of collaboration and confident decision-making enabled by the technology combination.
#
# **Chapter 7: Conclusion (04:12 - End)**
# * Recap the key points of the video and the benefits of using data agents and AI for business analysis.
# * Transition to the next segment or speaker.
#
# ## HTML Code for Chapter Index:
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Video Chapter Index</title
# >
# <style>
# table {
#   font-family: arial, sans-serif;
#   border-collapse: collapse;
#   width: 100%;
# }
#
# td, th {
#   border: 1px solid #dddddd;
#   text-align: left;
#   padding: 8px;
# }
#
# tr:nth-child(even) {
#   background-color: #dddddd;
# }
# </style>
# </head>
# <body>
#
# <h2>Video Chapter Index</h2>
#
# <table>
#   <tr>
#     <th>Chapter</th>
#     <th>
# Title</th>
#     <th>Description</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Introduction</td>
#     <td>(Fill in brief description)</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Data Agent Overview</td>
#     <td>(Fill in brief description)</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Analyzing Sales Trends</td>
#     <td>(Fill in brief description)</td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td>Supply and Demand Forecast</td>
#     <td>(Fill in brief description)</td>
#   </tr>
#   <tr>
#     <td>5
# </td>
#     <td>Similar Product Search</td>
#     <td>(Fill in brief description)</td>
#   </tr>
#   <tr>
#     <td>6</td>
#     <td>Actionable Insights and Collaboration</td>
#     <td>(Fill in brief description)</td>
#   </tr>
#   <tr>
#     <td>7</td>
#     <td>Conclusion</td>
#     <td>(Fill in brief description)</td>
#   </tr>
# </table>
#
# </body>
# </html>
# ```
#
# **Instructions:**
#
# 1. Replace the "(Fill in brief description)" placeholders with concise summaries of each chapter's content.
# 2. You can customize the table styles further
#  to match your preferences.
# 3.  Add specific timestamps for each chapter once you have identified them from the video.
#
# This HTML code will create a simple and organized table displaying the chapter index with titles and descriptions. You can easily embed this code within your webpage to present the information to your viewers.
#
# ## Chapter
#  Index for Wayfair & Google Cloud Generative AI Video:
#
# **00:00 - 00:03** - Introduction & Importance of
#  Developer Experience
# **00:03 - 00:14** - Wayfair's Focus on Generative AI for Developer Productivity
# **
# 00:14 - 00:27** - Choosing Gemini Code Assist & Pilot Results
# **00:27 - 00:59** - Improved Developer Productivity Metrics
# **00:59 - 01:13** - Wayfair's Ex
# citement & Collaboration with Google Cloud
# **01:13 - 02:02** -  Google's Internal Use & Customer Success Stories
# **02:02 - 02:53** -  Turing, Quantiphi & Commerzbank Experiences
# **02:
# 53 - 03:13** - Gemini Code Assist Features & Benefits
# **03:13 - 03:43** - Introducing Gemini 1.5 Pro & Gemini Cloud Assist
# **03:43 - 04:06** -  Benefits of Both Solutions & Demo Introduction
# **04:06 - End** - Demo of Gemini Code Assist for Personalized Product Recommendations
#
#
# ## HTML Code for Chapter
#  Index:
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Wayfair & Google Cloud Generative AI Video Index</title>
# <style>
# body {
#   font-family: sans-serif;
# }
# h2 {
#   color: #333;
# }
# ul {
#   list-style: none;
#   padding: 0;
# }
# li {
#   margin-
# bottom: 10px;
# }
# a {
#   color: #007bff;
#   text-decoration: none;
# }
# </style>
# </head>
# <body>
# <h2>Wayfair & Google Cloud Generative AI Video Index</h2>
# <ul>
#   <li><a href="#00:00">00:00 - 00:03</a> - Introduction & Importance of Developer Experience</li>
#   <li><a href="#00:03">00:03 - 00:14</a
# > - Wayfair's Focus on Generative AI for Developer Productivity</li>
#   <li><a href="#00:14">00:14 - 00:27</a> - Choosing Gemini Code Assist & Pilot Results </li>
#   <li><a href="#00:27">00:27 - 00:59</a> - Improved Developer Productivity Metrics</li>
#   <li><a href="#00:59">00:59 - 01:13</a> - Wayfair's
#  Excitement & Collaboration with Google Cloud</li>
#   <li><a href="#01:13">01:13 - 02:02</a> -  Google's Internal Use & Customer Success Stories</li>
#   <li><a href="#02:02">02:02 - 02:53</a> -  Turing, Quantiphi & Commerzbank Experiences</li>
#   <li><a href="#02:53">02:53 - 03:13</a> - Gemini
#  Code Assist Features & Benefits </li>
#   <li><a href="#03:13">03:13 - 03:43</a> - Introducing Gemini 1.5 Pro & Gemini Cloud Assist</li>
#   <li><a href="#03:43">03:43 - 04:06</a> -  Benefits of Both Solutions & Demo Introduction</li>
#   <li><a href="#04:06">04:06 - End</a> - Demo of Gemini Code Assist for Personalized Product Recommendations </
# li>
# </ul>
# </body>
# </html>
# ```
#
# **Note:** This HTML code provides a basic structure for the chapter index. You can further customize the styling and functionality as needed. Remember to add ID attributes to your video element corresponding to each chapter timestamp to enable direct linking from the index.
#
# ## Chapter
#  Index for "Google Cloud Next '23" video:
#
# **Please note that the timestamps are based on the provided transcript and may not be perfectly accurate.
#  It's recommended to use them as a general guide.**
#
# **0:00 - 3:30: Gemini Code Assist**
#
# *
# Introduction to the challenges faced by new engineers onboarding to large codebases.
# *   Introducing Gemini Code Assist as a solution for increased productivity.
# *   Demonstration of Gemini's ability to understand and generate code based on natural language prompts.
# *   Highlighting Gemini's codebase awareness and reasoning capabilities.
#
# *   Comparison of Gemini to other models and its advantage in handling large codebases.
# *   Example of using Gemini Code Assist to add a new feature to the "Symbol Outfitters" application.
# *   Recap of Gemini's benefits for developers and teams.
#
# **3:30 - 4:
# 55: Security and Generative AI**
#
# *   Introduction of Google Cloud's focus on security within generative AI.
# *   Three key areas of emphasis:
#     *   Data privacy and security controls (data location, encryption, access control, auditing)
#     *   Protection of models and agents from cyberattacks (e.g., malicious prompt injection)
#     *   Assisting SecOps teams with faster prevention, detection, and response.
# *
# Mention of collaboration with Palo Alto Networks in building secure generative AI solutions.
#
# **4:55 - End: Palo Alto Networks and Google Cloud Partnership**
#
# *   Introduction of Nikesh Arora, CEO of Palo Alto Networks.
# *   Discussion of the shared vision between Google Cloud and Palo Alto Networks for implementing generative AI in security solutions.
#
# ## HTML Code for Chapter Index:
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#
# <title>Chapter Index</title>
#   <style>
#     body {
#       font-family: sans-serif;
#     }
#     h1 {
#       text-align: center;
#     }
#     table {
#       width: 100%;
#       border-collapse: collapse;
#     }
#     th, td {
#       border: 1px solid #ddd;
#       padding: 8px;
#       text-align: left;
#     }
#   </style>
# </head>
# <body>
#   <h1>Chapter Index</h1>
#   <table>
#
#     <tr>
#       <th>Timestamp</th>
#       <th>Chapter Title</th>
#       <th>Description</th>
#     </tr>
#     <tr>
#       <td>0:00 - 3:30</td>
#       <td>Gemini Code Assist</td>
#       <td>Introduction and demonstration of Gemini's capabilities for boosting developer productivity.</td>
#     </tr>
#     <tr>
#       <td>3:30 - 4:55</td>
#       <td>Security and Generative AI</td>
#       <td>Google Cloud's approach to security in generative AI, focusing on data protection, model security, and SecOps assistance.</td>
#     </tr>
#     <tr>
#
# <td>4:55 - End</td>
#       <td>Palo Alto Networks and Google Cloud Partnership</td>
#       <td>Collaboration between the two companies to implement generative AI for enhanced security solutions.</td>
#     </tr>
#   </table>
# </body>
# </html>
# ```
#
# **This HTML code will generate a simple table with three columns: Timestamp, Chapter Title, and Description. You can customize the styling and add more information as needed.**
#
# ## Chapter
#  Index for Video:
#
# **Based on the information provided, here's a possible chapter index for the video:**
#
# * **00:00 -
#  Introduction:** Nikesh Arora, CEO of Palo Alto Networks, discusses the shift towards a new paradigm in cybersecurity.
# * **00:05 - Collaboration
#  with Google:** Highlighting the partnership with Google to build cloud security capabilities.
# * **00:10 - Cortex XSIAM Platform:** Introduction to Cortex XSIAM, a platform that leverages AI and machine learning to reinvent security operations.
# * **00:24 - Benefits of AI in
#  Security:** Discussing the advantages of using AI, including faster detection, increased accuracy, and improved explainability.
# * **00:51 - Google Cloud and Gemini:**  Explaining the integration of Gemini with Palo Alto Networks' products and the potential for further advancements in ease of use and automation.
#
#
# ## HTML Code for Chapter Index:
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Video Chapter Index</title>
#   <style>
#     body {
#       font-family: sans-serif;
#     }
#     h2 {
#       color: #333;
#     }
#     ul {
#       list-style: none;
#       padding: 0;
#     }
#
#     li {
#       margin: 10px 0;
#     }
#     a {
#       color: #007bff;
#       text-decoration: none;
#     }
#   </style>
# </head>
# <body>
#   <h2>Video Chapter Index</h2>
#   <ul>
#     <li><a href="#00:00">00:00 - Introduction</a></li>
#     <
# li><a href="#00:05">00:05 - Collaboration with Google</a></li>
#     <li><a href="#00:10">00:10 - Cortex XSIAM Platform</a></li>
#     <li><a href="#00:24">00:24 - Benefits of AI in Security</a></li>
#     <li><a href="#00:51">00:51 - Google Cloud and Gemini</a></li>
#   </ul>
# </body>
# </html>
#
# ```
#
# **Please note:** This HTML code assumes the video is embedded on the same page and the timestamps correspond to anchor points within the video. You may need to adjust the code based on your specific implementation.
#
# ##
#  Chapter Index for Google Cloud Next Video:
#
# **I am unable to create
#  a specific chapter index and corresponding HTML code without more information about the video content.**
#  However, I can provide you with a template and guide you on how to fill it in based on the video you're referencing.
#
# **Template Chapter
#  Index (HTML):**
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Chapter Index</title>
#
# </head>
# <body>
#   <h1>Chapter Index</h1>
#   <ol>
#     <li><a href="#00:00">Introduction & Google Cloud Partner Ecosystem (00:00)</a></li
# >
#     <li><a href="#00:06">Partnerships & Infrastructure (00:06)</a></li>
#     <!-- Add more chapters here -->
#   </ol>
# </body>
#
# </html>
# ```
#
# **Instructions:**
#
# 1. **Identify Key Topics:** Watch the video and note down the main topics discussed and the timestamps where they begin.
# 2. **Create Chapter Titles:** Summarize each key topic with a concise and informative chapter title.
# 3. **Update HTML:**
#
#     *  Replace the example chapters with your own, using the format:
#         * `<li><a href="#timestamp">Chapter Title (Timestamp)</a></li>`
#     * Make sure the timestamps match the actual starting point of each chapter in the video.
# 4. **Implementation (Optional):
# **
#     * **Video Platforms:** Some video platforms like YouTube allow you to add chapters directly in the video description or settings.
#     * **Interactive Websites:** You can embed the video on a webpage and link the chapter timestamps to jump to specific points in the video player.
#
# **Example Chapters (Based
#  on Limited Information):**
#
# * **00:00 - Introduction & Google Cloud Partner Ecosystem**
# * **00:06 - Partnerships & Infrastructure**
# * **00:11 - Customer and Partner Appreciation**
# * **00:13 - Upcoming Sessions & Keynotes**
#
# * **00:20 - Building the New Cloud**
#
# **Remember to replace these examples with the actual content of your video. I hope this helps! Let me know if you have any other questions.**
